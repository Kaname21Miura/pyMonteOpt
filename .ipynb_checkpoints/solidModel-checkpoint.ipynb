# %%
import time
#import cupy as cu
import numpy as np
import readDICOM as dcm
import matplotlib.pyplot as plt
import matplotlib
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
import os
workspace = os.getcwd()
def calTime(end, start):
    elapsed_time = end - start
    q, mod = divmod(elapsed_time, 60)
    if q < 60:
        print('Calculation time: %d minutes %d seconds.' % (q, mod))
    else:
        q2, mod2 = divmod(q, 60)
        print('Calculation time: %d h %d minutes.' % (q2, mod2))

# %% [markdown]
# # Monte Carlo class

# %%
class MonteCalroPh():
    def __init__(self,sample_model):
        self.model = sample_model
        self.vectorTh = 0.99999
        
    def generateInisalData(self,nPh,f_bit):
        p = np.zeros((3,nPh),dtype = f_bit)
        v = np.zeros((3,nPh),dtype = f_bit)
        v[2] = 1
        w = self.initialWeight(np.full(nPh,1).astype(f_bit))
        return p,v,w
    
    def initialWeight(self,w):
        Rsp = 0
        n1 = self.model.ref_index[0]
        n2 = self.model.ref_index[1]
        if n1 != n2:
            Rsp = (n1-n2)**2/(n1+n2)**2
        return w-Rsp
    
    ####### Mainの関数 #######
    def startMonteCalro(self,nPh):

        f_bit = "float32"
        start_ = time.time()

        #初期値の設定
        p,v,w = self.generateInisalData(nPh,f_bit)

        #結果保存用の配列を定義
        v_result = np.empty((3,1)).astype(f_bit)
        p_result = np.empty((3,1)).astype(f_bit)
        w_result = np.empty(1).astype(f_bit)
        count = 0
        counter = 2
        trace = []
        # Let's MonteCalro!
        while list(w) != []:
            
            p,v,w,result = self.stepMovement(p,v,w,f_bit)
            #trace.append(p)
            if result[0][0].tolist() != []:
                p_result = np.concatenate([p_result, result[0]],axis = 1)
                v_result = np.concatenate([v_result, result[1]],axis = 1)
                w_result = np.concatenate([w_result, result[2]])
            count+=1
            if count%counter==0:
                counter*=2
                print("Progress: %s [％]"%round((1-w.size/nPh)*100,3))
                calTime(time.time(), start_)
                print()

        #結果の表示
        print("")
        print("###### Result ######")
        print("Maximum step number: %s"%count)
        print("Photon weight reduction late: %s ％"%round((1-np.sum(w_result)/nPh)*100,3))
        calTime(time.time(), start_)
        v_result = v_result[:,1:]
        p_result = p_result[:,1:]
        w_result = w_result[1:]
        return v_result,p_result,w_result,trace
    
    #光の動きを制御する
    def stepMovement(self,p,v,w,f="float32"):
        ## 光子の位置並びにベクトルを更新します。
        #１stepで光子が進む予定の距離を定義
        s = self.stepLength(p[0].size,f)
        #境界を超える光子のindexを取得
        pb_index,l,ma,mt,g = self.model.boundaryJudgment(p,v,s)
        #光子位置を更新
        p = self.positionUpdate(p,v,l)
        
        if list(pb_index) != []:
            #境界上光子のベクトルの更新
            v[:,pb_index] = self.updateOnBoundary(v[:,pb_index],p[:,pb_index],f)
            #境界を超えない光子の位置,ベクトルを更新
            pn_index = np.delete(np.arange(p[2].size),pb_index)
            v[:,pn_index] = self.vectorUpdate(v[:,pn_index],g[pn_index],f)
            w[pn_index] = self.wUpdate(w[pn_index],ma[pn_index],mt[pn_index],1)
            
        else:#全ての光子が境界に乗っていない時
            v= self.vectorUpdate(v,g,f)
            w = self.wUpdate(w,ma,mt,1)
            
        p,v,w,result=self.model.borderOut(p,v,w)
        w,p,v = self.photonVanishing(w,p,v)
        return p,v,w,result

    def photonVanishing(self,w,p,v):
        #photn waight が0.0001以下
        del_index = np.where(w<=0.0001)[0]
        if list(del_index) != []:
            w[del_index] = self.russianRoulette(w[del_index])
            del_index = np.where(w==0)[0]
            v = np.delete(v, del_index, axis = 1)
            p = np.delete(p, del_index, axis = 1)
            w = np.delete(w, del_index)
        else:
            pass
        return w,p,v
    
    def russianRoulette(self,w,f="float32"):
        ## 確率的に光子を生き返らせます。
        m = 10
        ra = np.random.rand(w.size).astype(f)
        index = np.where(ra>(1/m))[0].tolist()
        w[index] = 0
        index = np.where(ra<=(1/m))[0].tolist()
        w[index] = w[index]*m
        return w
    
    #境界におけるベクトル更新
    def updateOnBoundary(self,v,p,f="float32"):
        ## ここでは、透過判別や反射、屈折の計算を行います。
        
        #境界を超える前後の屈折率を取得  
        ni,nt = self.model.getNiNt(p,v)
        #境界前後で屈折率が変化する場合のindex
        pb_index = np.where(ni!=nt)[0]
        
        if list(pb_index) != []:
            #透過判別
            #入射角の計算
            ai = self.model.getIncidentAngle(v[:,pb_index])
            #全反射するときのインデックスを取得
            sub_index = np.where((ai>=np.arcsin(nt[pb_index]/ni[pb_index]))&(nt[pb_index]<ni[pb_index]))[0]
            #屈折角の計算
            ##(ai,at)=(0,0)の時は透過させ方向ベクトルは変化させない
            at = np.arcsin(ni[pb_index]*np.sin(ai)/nt[pb_index])
            Ra = np.random.rand(ai.size)\
            -((np.sin(ai-at)/np.sin(ai+at))**2+(np.tan(ai-at)/np.tan(ai+at))**2)/2
            #全反射はRaを強制的に0以下にし反射させる
            Ra[sub_index] = -1
            #透過と反射のindexを取得
            vl_index = pb_index[np.where(Ra<=0)[0]]#反射
            sub_index = np.where(Ra>0)[0]
            vt_index = pb_index[sub_index]#透過
            at = at[sub_index]
            #ベクトルを更新
            v = self.model.boundaryVectorUpdate(v,at,ni/nt,vl_index,vt_index)
        return v

    def vectorUpdate(self,v,G,f="float32"):
        index = np.where(G==0.0)[0]
        cosTh = np.empty_like(G)
        if list(index) != []:
            rand_num = np.random.rand(G.size).astype(f)
            cosTh[index] = 2*rand_num[index]-1
            index = np.where(G!=0)[0]
            if list(index) != []:
                cosTh[index] = ((1+G[index]**2\
                                 -((1-G[index]**2)/(1-G[index]+2*G[index]*rand_num[index]))**2)/(2*G[index]))
        else:
            #cos(theta)とsin(theta)と求める
            cosTh = ((1+G**2-((1-G**2)/(1-G+2*G*np.random.rand(G.size).astype(f)))**2)/(2*G))
            
        sinTh = np.sqrt(1-cosTh**2)
        
        #cos(fai)とsin(fai)と求める
        Fi = 2*np.pi*np.random.rand(G.size).astype(f)
        cosFi = np.cos(Fi)
        sinFi = np.sin(Fi)
        
        #Zが１かそれ以外で分離
        th = self.vectorTh
        v1_index = np.where(np.abs(v[2])<=th)[0]
        v2_index = np.where(np.abs(v[2])>th)[0]
        
        if list(v1_index) != []:
            #Z方向ベクトルが0.99999以下
            v1 = v[:,v1_index]
            cosTh1 = cosTh[v1_index]; sinTh1 = sinTh[v1_index]
            cosFi1 = cosFi[v1_index]; sinFi1 = sinFi[v1_index]
            A = np.array([
                sinTh1*(v1[0]*v1[2]*cosFi1-v1[1]*sinFi1)/np.sqrt(1-v1[2]**2),
                sinTh1*(v1[1]*v1[2]*cosFi1+v1[0]*sinFi1)/np.sqrt(1-v1[2]**2),
                -sinTh1*cosFi1*np.sqrt(1-v1[2]**2),
            ])
            v[:,v1_index] = A+v1*cosTh1
            
        if list(v2_index) != []:
            #Z方向ベクトルが0.99999以上
            v1 = v[:,v2_index]
            cosTh1 = cosTh[v2_index]; sinTh1 = sinTh[v2_index]
            cosFi1 = cosFi[v2_index]; sinFi1 = sinFi[v2_index]
            
            v[:,v2_index] = np.array([
                sinTh1*cosFi1,
                sinTh1*sinFi1,
                np.sign(v1[2])*cosTh1,
            ],dtype=f)
        return v

    def positionUpdate(self,p,v,L):
        return p+v*L

    #光子の１ステップにおけるエネルギーの損失を計算
    def wUpdate(self,w,ma,mt,rato):
        return w*(1-rato*ma/mt)
    
    def russianRoulette(self,w,f="float32"):
        ## 確率的に光子を生き返らせます。
        m = 10
        ra = np.random.rand(w.size).astype(f)
        index = np.where(ra>(1/m))[0].tolist()
        w[index] = 0
        index = np.where(ra<=(1/m))[0].tolist()
        w[index] = w[index]*m
        return w

    #光子の移動距離, uniformly distributed over the interval (0,1)
    def stepLength(self,size,f="float32"):
        return -np.log(np.random.rand(size)).astype(f)
 
    
class SolidPlateModel():
    def __init__(self,thickness,ma_list,ms_list,g_list,n_list,n_air,f = 'float32'):
        thickness = [0]+thickness
        b = 0; b_list = []
        for i in  thickness:
            b += i
            b_list.append(b)
        self.f = f
        self.borderposit = np.array(b_list).astype(f)
        self.ref_index =np.array([n_air]+n_list+[n_air]).astype(f)
        self.ms = np.array(ms_list).astype(f)
        self.ma = np.array(ma_list).astype(f)
        self.g = np.array(g_list).astype(f)
    
    # 境界への入射角を定義
    def getIncidentAngle(self,v):
        return np.arccos(abs(v[2]))

    def getDistanceBoundary(self,p,v):
        index_positive = np.where(v[2]>0)[0]
        index_negative = np.where(v[2]<0)[0]
        index_zero = np.where(v[2]==0)[0]

        index_border = self.getBorderIndex(p)

        border = self.borderposit
        tilearray = np.tile(border,(p[2].size,1))

        shallow = (tilearray*self.create01Array(index_border,m=border.size).T).max(1)
        deep = (tilearray*self.create01Array(index_border+1,m=border.size).T).max(1)

        S = np.empty_like(p[2])
        S[index_negative] = (shallow[index_negative] - p[2,index_negative])/v[2,index_negative]
        S[index_positive] = (deep[index_positive] - p[2,index_positive])/v[2,index_positive]
        S[index_zero]=10000
        return abs(S)
    
    def getOpticalProperties(self,p):
        ma_array = self.ma; ms_array = self.ms; g_array = self.g
        index = self.getBorderIndex(p)
        data = np.empty((3,p[2].size))
        p_size = p[2].size
        A = self.create01Array(index,m=ma_array.size).T
        data[0] = (np.tile(ma_array,(p_size,1))*A).max(1)
        data[1] = (np.tile(ms_array,(p_size,1))*A).max(1)
        data[2] = (np.tile(g_array,(p_size,1))*A).max(1)
        return data
                   
    def getBorderIndex(self,p):
        border = self.borderposit
        d = np.sign(np.tile(border,(p[2].size,1))-np.tile(p[2],(border.size,1)).T).astype('int16')
        return np.where(d[:,:-1] != d[:,1:])[1]
                   
    #屈折率ni,ntの取得
    def getNiNt(self,p,v):
        ind_negative = np.where(v[2]<0)[0]
        ind_positive = np.where(v[2]>0)[0]
        pz = p[2]
        n = self.ref_index
        border = self.borderposit
        index = np.argmin(np.abs(np.tile(border,(pz.size,1))-np.tile(pz,(border.size,1)).T),axis = 1)
        n_array = np.tile(n,(index.size,1)).T
        shallow = (n_array*self.create01Array(index,m=border.size+1)).max(0)
        deep = (n_array*self.create01Array(index+1,m=border.size+1)).max(0)

        ni = np.empty_like(pz)
        nt = np.empty_like(pz)
        ni[ind_positive] = shallow[ind_positive]
        ni[ind_negative] = deep[ind_negative]
        nt[ind_positive] = deep[ind_positive]
        nt[ind_negative] = shallow[ind_negative]
        return ni,nt
    
    #任意の位置(indexの行)が１でそれ以外は0の行列を作る
    def create01Array(self,index,m=3):
        n = index.size
        array_0_1 = np.zeros(m*n,dtype = bool)
        array_0_1[np.add(index,m*np.arange(n))] = 1
        return array_0_1.reshape(n,m).T 
    
    # 境界判別と光子移動距離の更新
    def boundaryJudgment(self,p,v,s):
        ma,ms,g = self.getOpticalProperties(p)
        db = self.getDistanceBoundary(p,v)
        mt = ma+ms
        s = s/mt
        pb_index = np.where((s-db)>=0)[0]
        s[pb_index] = db[pb_index]
        return pb_index,s,ma,mt,g
    
    def borderOut(self,p,v,w):
        margin = 1e-8
        border = self.borderposit
        del_index = np.where(((p[2]<=border[0]+margin)&(v[2]<0))|((p[2]>=border[-1]-margin)&(v[2]>0)))[0]
        result = list([p[:,del_index],v[:,del_index],w[del_index]])
        index = np.where((p[2]<=border[0])&(v[2]>0))[0]
        p[2,index] = border[0]
        index = np.where((p[2]>=border[-1])&(v[2]<0))[0]
        p[2,index] = border[-1]
        
        v = np.delete(v, del_index, axis = 1)
        p = np.delete(p, del_index, axis = 1)
        w = np.delete(w, del_index)
        return p,v,w,result
    
    # 境界上のベクトル更新
    def boundaryVectorUpdate(self,v,at,snell_rato,vl_index,vt_index):
        #反射するとき
        if list(vl_index) !=[]:
            v[2,vl_index] = -v[2,vl_index]
            
        #透過するときのベクトルを更新
        if list(vt_index)!=[]:
            v[0,vt_index] = snell_rato[vt_index]*v[0,vt_index]
            v[1,vt_index] = snell_rato[vt_index]*v[1,vt_index]
            v[2,vt_index] = np.sign(v[2,vt_index])*np.cos(at)
        return v

# %% [markdown]
# # Test code

# %%
thickness=[200]
ms = [90]
ma = [10]
g = [0.]
n = [1.5]
n_air = 1.
model = SolidPlateModel(thickness,ma,ms,g,n,n_air)
monte = MonteCalroPh(model)
nPh = 5000
v_result,p_result,w_result,trace = monte.startMonteCalro(nPh)

# %% [markdown]
# ## Total diffuse reflectance and total transmittance

# %% [markdown]
# ### slab of turbid medium

# %%
thickness=[0.02]
ms = [90]
ma = [10]
g = [0.75]
n = [1.]
n_air = 1.
model = SolidPlateModel(thickness,ma,ms,g,n,n_air)
monte = MonteCalroPh(model)
nPh = 50000

margin = 1e-6
Tt = []; Rd = []
for i in range(50):
    v_result,p_result,w_result,trace = monte.startMonteCalro(nPh)
    Tt_index = np.where(p_result[2]>=thickness[0]-margin)[0]
    Rd_index = np.where(p_result[2]<=margin)[0]
    Tt.append(w_result[Tt_index].sum()/nPh)
    Rd.append(w_result[Rd_index].sum()/nPh)
    print('######')
    print('Mean Tt %0.6f'%Tt[-1])
    print('Mean Rd %0.6f'%Rd[-1])
    print()
# Out:
# Progress: 36.11 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.092 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.884 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.19 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.178 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659159
# Mean Rd 0.099066
#
# Progress: 36.108 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.032 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.614 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.188 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.984 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 38
# Photon weight reduction late: 24.228 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661037
# Mean Rd 0.096679
#
# Progress: 35.848 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.218 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.778 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.188 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 32
# Photon weight reduction late: 24.174 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660751
# Mean Rd 0.097511
#
# Progress: 35.616 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.232 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.818 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.24 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 37
# Photon weight reduction late: 24.209 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661463
# Mean Rd 0.096446
#
# Progress: 36.094 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.906 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.948 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.148 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 40
# Photon weight reduction late: 24.173 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659737
# Mean Rd 0.098535
#
# Progress: 35.82 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.848 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.852 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.242 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.265 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.656109
# Mean Rd 0.101242
#
# Progress: 36.15 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.178 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.976 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.272 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.119 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660468
# Mean Rd 0.098338
#
# Progress: 35.638 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.798 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.792 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.13 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 43
# Photon weight reduction late: 24.369 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659748
# Mean Rd 0.096564
#
# Progress: 35.546 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.964 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.782 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.218 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 36
# Photon weight reduction late: 24.246 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659126
# Mean Rd 0.098419
#
# Progress: 35.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.186 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.796 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.226 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 41
# Photon weight reduction late: 24.127 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.663151
# Mean Rd 0.095578
#
# Progress: 36.022 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.632 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.214 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 35
# Photon weight reduction late: 24.028 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662787
# Mean Rd 0.096936
#
# Progress: 36.158 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.462 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.862 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.218 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.986 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.079 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.663855
# Mean Rd 0.095357
#
# Progress: 36.074 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.28 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.154 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.204 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 38
# Photon weight reduction late: 24.069 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662851
# Mean Rd 0.096458
#
# Progress: 36.124 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.852 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.202 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 33
# Photon weight reduction late: 24.153 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660749
# Mean Rd 0.097723
#
# Progress: 35.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.894 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.874 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.21 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.988 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 42
# Photon weight reduction late: 24.211 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.658408
# Mean Rd 0.099484
#
# Progress: 36.052 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.148 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.94 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.154 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 36
# Photon weight reduction late: 24.136 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662105
# Mean Rd 0.096535
#
# Progress: 36.14 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.284 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.986 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 42
# Photon weight reduction late: 24.077 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661585
# Mean Rd 0.097647
#
# Progress: 36.056 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.282 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.95 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.218 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.143 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661468
# Mean Rd 0.097102
#
# Progress: 35.784 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.034 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.802 [％]
# Calculation time: 0 minutes 0 seconds.
# Progress: 99.222 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.264 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660920
# Mean Rd 0.096443
#
# Progress: 35.814 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.11 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.974 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.988 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 45
# Photon weight reduction late: 24.184 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660511
# Mean Rd 0.097648
#
# Progress: 36.14 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.954 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.918 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.206 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 40
# Photon weight reduction late: 24.18 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662481
# Mean Rd 0.095718
#
# Progress: 36.412 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.63 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.98 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.194 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.986 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 45
# Photon weight reduction late: 24.018 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662824
# Mean Rd 0.096993
#
# Progress: 35.774 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.048 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.06 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.182 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662180
# Mean Rd 0.096002
#
# Progress: 35.608 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.89 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.67 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.216 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 37
# Photon weight reduction late: 24.331 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659611
# Mean Rd 0.097080
#
# Progress: 35.906 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.28 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.064 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.158 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 35
# Photon weight reduction late: 24.103 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660716
# Mean Rd 0.098250
#
# Progress: 35.65 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.666 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.89 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.152 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.982 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 44
# Photon weight reduction late: 24.337 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.657760
# Mean Rd 0.098874
#
# Progress: 36.158 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.094 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.708 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.174 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 44
# Photon weight reduction late: 24.186 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662349
# Mean Rd 0.095792
#
# Progress: 36.234 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.984 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.714 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.162 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 48
# Photon weight reduction late: 24.186 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660179
# Mean Rd 0.097960
#
# Progress: 35.976 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.092 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.776 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.126 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 45
# Photon weight reduction late: 24.222 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659395
# Mean Rd 0.098390
#
# Progress: 35.854 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.178 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.594 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.226 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 45
# Photon weight reduction late: 24.282 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659782
# Mean Rd 0.097401
#
# Progress: 35.646 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.852 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.906 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.192 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 37
# Photon weight reduction late: 24.272 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660655
# Mean Rd 0.096627
#
# Progress: 36.182 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.264 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.942 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.196 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 44
# Photon weight reduction late: 24.095 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661665
# Mean Rd 0.097388
#
# Progress: 36.362 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.272 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.016 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.246 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.075 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661976
# Mean Rd 0.097270
#
# Progress: 36.058 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.88 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.226 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 35
# Photon weight reduction late: 24.187 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661120
# Mean Rd 0.097012
#
# Progress: 35.844 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.292 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.894 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.19 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.124 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660716
# Mean Rd 0.098041
#
# Progress: 36.35 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.256 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.96 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.162 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.053 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660294
# Mean Rd 0.099172
# Progress: 35.648 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.958 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.756 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.208 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 37
# Photon weight reduction late: 24.274 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660014
# Mean Rd 0.097250
#
# Progress: 36.06 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.178 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.946 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.204 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 34
# Photon weight reduction late: 24.127 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661265
# Mean Rd 0.097462
#
# Progress: 36.076 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.124 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.964 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.196 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 38
# Photon weight reduction late: 24.16 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662066
# Mean Rd 0.096332
#
# Progress: 35.568 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.832 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.942 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.226 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 35
# Photon weight reduction late: 24.309 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.658481
# Mean Rd 0.098424
#
# Progress: 35.798 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.878 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.814 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.144 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.298 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.657891
# Mean Rd 0.099133
#
# Progress: 36.388 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.466 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.9 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.216 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 37
# Photon weight reduction late: 24.027 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.663684
# Mean Rd 0.096044
#
# Progress: 35.932 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.45 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.03 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.218 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 40
# Photon weight reduction late: 24.079 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.662558
# Mean Rd 0.096654
#
# Progress: 36.036 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.038 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.942 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.17 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.988 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.167 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660848
# Mean Rd 0.097485
#
# Progress: 36.152 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.074 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.906 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.216 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 40
# Photon weight reduction late: 24.151 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661561
# Mean Rd 0.096924
#
# Progress: 36.254 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.314 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.966 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.21 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 48
# Photon weight reduction late: 24.074 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661204
# Mean Rd 0.098058
#
# Progress: 36.15 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.332 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.888 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.204 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 36
# Photon weight reduction late: 24.098 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.661752
# Mean Rd 0.097267
#
# Progress: 35.626 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.96 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.674 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.226 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.984 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.286 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.660469
# Mean Rd 0.096667
#
# Progress: 35.708 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.042 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.754 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.176 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 35
# Photon weight reduction late: 24.241 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.659480
# Mean Rd 0.098106
#
# Progress: 35.822 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.002 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.846 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.196 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 39
# Photon weight reduction late: 24.206 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.658907
# Mean Rd 0.099031

# %%
print('Mean Tt %0.6f, sd_error %0.6f'%(np.mean(Tt),np.std(Tt)/np.sqrt(len(Tt))))
print('Mean Rd %0.6f, sd_error %0.6f'%(np.mean(Rd),np.std(Rd)/np.sqrt(len(Rd))))
# Out:
# Mean Tt 0.660797, sd_error 0.000223
# Mean Rd 0.097451, sd_error 0.000162

# %% [markdown]
# ### Semi-infinite turbid medium

# %%
thickness=[2000]
ms = [90]
ma = [10]
g = [0]
n = [1.5]
n_air = 1.
model = SolidPlateModel(thickness,ma,ms,g,n,n_air)
monte = MonteCalroPh(model)
nPh = 5000

margin = 1e-8
Tt = []; Rd = []
for i in range(10):
    v_result,p_result,w_result,trace = monte.startMonteCalro(nPh)
    Tt_index = np.where(p_result[2]>=thickness[0]-margin)[0]
    Rd_index = np.where(p_result[2]<=margin)[0]
    Tt.append(w_result[Tt_index].sum()/nPh)
    Rd.append(w_result[Rd_index].sum()/nPh)
    print('######')
    print('Mean Tt %0.6f'%Tt[-1])
    print('Mean Rd %0.6f'%Rd[-1])
    print()
# Out:
# Progress: 5.34 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 13.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.18 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.84 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 154
# Photon weight reduction late: 77.741 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.222587
#
# Progress: 6.3 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 13.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 24.26 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.88 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.42 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.72 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 178
# Photon weight reduction late: 77.142 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.228569
#
# Progress: 5.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.32 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.72 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 50.52 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 62.42 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 175
# Photon weight reduction late: 77.762 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.222370
#
# Progress: 5.08 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.18 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 48.64 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 155
# Photon weight reduction late: 78.22 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.217793
#
# Progress: 5.44 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.24 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.58 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.92 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.42 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.7 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 135
# Photon weight reduction late: 78.098 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.219012
#
# Progress: 4.88 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 11.72 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.5 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 48.24 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 60.52 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.7 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 137
# Photon weight reduction late: 78.612 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.213873
#
# Progress: 5.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 13.18 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.84 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 50.34 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 63.46 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.76 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 137
# Photon weight reduction late: 77.417 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.225825
#
# Progress: 5.38 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.2 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.82 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.38 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 48.46 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 60.74 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.7 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 154
# Photon weight reduction late: 78.293 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.217067
#
# Progress: 5.5 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.8 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.9 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.26 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.08 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.1 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.58 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 154
# Photon weight reduction late: 77.829 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.221705
#
# Progress: 5.58 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.86 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 37.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 51.08 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 63.34 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.66 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 153
# Photon weight reduction late: 77.295 ％
# Calculation time: 0 minutes 0 seconds.
# ######
# Mean Tt 0.000000
# Mean Rd 0.227045

# %%
print('Mean Tt %0.6f, sd_error %0.6f'%(np.mean(Tt),np.std(Tt)/np.sqrt(len(Tt))))
print('Mean Rd %0.6f, sd_error %0.6f'%(np.mean(Rd),np.std(Rd)/np.sqrt(len(Rd))))
# Out:
# Mean Tt 0.000000, sd_error 0.000000
# Mean Rd 0.219165, sd_error 0.001874

# %%
thickness=[200]
ms = [90]
ma = [10]
g = [0.]
n = [1.5]
n_air = 1.
model = SolidPlateModel(thickness,ma,ms,g,n,n_air)
monte = MonteCalroPh(model)
nPh = 1
v_result,p_result,w_result,trace = monte.startMonteCalro(nPh)
trace = np.array(trace[:-1])
plt.plot(traice[:,0],traice[:,2]*-1,'-')
plt.show()
# Out:
# Progress: 0.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 0.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 0.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 0.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 0.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 0.0 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Result ######
# Maximum step number: 88
# Photon weight reduction late: 90.0 ％
# Calculation time: 0 minutes 0 seconds.

# %%
traice = np.array(save_p[:-1])
plt.plot(traice[:,0],traice[:,2]*-1,'-')
plt.show()

# %%
def saveFile(v,p,add,w,fname = "test.csv"):
    ## 結果保存用の関数です。
    ## 計算結果は、csv形式で保存されます。
    ## x,y,ux,uy,uz,wの順で保存されます。
    
    start_ = time.time()
    hnit = ((add[0:2]-ConstPixelDims[0]/2)*ConstPixelSpacing[0]+ConstPixelSpacing[0]/2+p[0:2]).astype("float32")
    list_sample = np.array([hnit[0],hnit[1],v[0],v[1],v[2],w]).T
    f = open(fname,'w')
    try:
        for i in range(len(list_sample)):
            for j in range (len(list_sample[i])-1):
                sub_list = round(list_sample[i][j],6)
                f.write(str(sub_list))
                f.write(',')
            sub_list = round(list_sample[i][len(list_sample[i])-1],6)
            f.write(str(sub_list))
            f.write('\n')
            if list_sample[i][4] == 0:
                break
        time.sleep(1.0)
    finally:
        f.close
    fig = plt.figure(figsize=(10,6),dpi=200)
    ax = fig.add_subplot(111)
    ax.set_aspect('equal')
    y = hnit[1]
    x = hnit[0]
    H = ax.hist2d(x,y, bins=2**10,cmap="plasma",norm=matplotlib.colors.LogNorm())
    ax.set_title('hist map')
    ax.set_xlabel('X [mm]')
    ax.set_ylabel('Y [mm]')
    fig.colorbar(H[3],ax=ax)
    plt.show()
    calTime(time.time(), start_)
    print("File name: %s"%fname)
    

def gaussianBeam(nPh,w=0.54):
    #TEM00のビームを生成します
    r = np.linspace(-w*2,w*2,100)
    #Ir = 2*np.exp(-2*r**2/(w**2))/(np.pi*(w**2))
    Ir = np.exp(-2*r**2/(w**2))
    normd = stats.norm(0, w/2)
    x = normd.rvs(nPh)
    y = normd.rvs(nPh)
    z = np.zeros(nPh)

    fig, ax1 = plt.subplots()
    ax1.set_title('Input laser light distribution')
    ax1.hist(x, bins=100, color="C0")
    ax1.set_ylabel('Number of photon')
    ax2 = ax1.twinx()
    ax2.plot(r, Ir, color="k")
    ax2.set_xlabel('X [mm]')
    ax2.set_ylabel('Probability density')
    plt.show()

    fig = plt.figure(figsize=(10,6),dpi=70)
    ax = fig.add_subplot(111)
    ax.set_aspect('equal')
    H = ax.hist2d(x,y, bins=100,cmap="plasma")
    ax.set_title('Histogram for laser light intensity')
    ax.set_xlabel('X [mm]')
    ax.set_ylabel('Y [mm]')
    fig.colorbar(H[3],ax=ax)
    plt.show()
    return x,y
