# %%
from pymopt.voxel import VoxelPlateModel

from scipy import stats
import numpy as np
import pandas as pa
import time

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
sns.set_style("ticks", {'grid.linestyle': '--'})
import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import ParameterGrid
from sklearn.metrics import r2_score
cp = sns.color_palette(n_colors=24)

# %%
def radialDistance(p,w,nn,dr):
    alpha = np.array([(i)*dr for i in range(nn+1)])
    da = np.array([2*np.pi*(i+0.5)*dr**2 for i in range(nn)])
    r = np.sqrt(p[0]**2+p[1]**2)
    Rdr = []
    for i in range(nn):
        index = np.where((alpha[i]<r)&(alpha[i+1]>=r))[0]
        Rdr.append(w[index].sum())
    Rdr = np.array(Rdr)/(da*nPh)
    return alpha[:-1],Rdr
def calc_alpha(nn,dr):
    alpha = np.array([(i)*dr for i in range(nn+1)])
    return alpha[:-1]

def lightIntensityDist(rez):
    nn = 100
    dr = 0.01
    p_result = rez["p"]
    v_result = rez["v"]
    w_result = rez["w"]

    Tt_index = np.where(v_result[2]>0)[0]
    Rd_index = np.where(v_result[2]<0)[0]

    _,Rd = radialDistance(p_result[:,Rd_index],w_result[Rd_index],nn,dr)
    _,Tt = radialDistance(p_result[:,Tt_index],w_result[Tt_index],nn,dr)
    return Rd,Tt

# %%
nPh = 5e5
grid_params={
    'thickness':[0.16,0.2,0.3],
    'g':[0.9,0.92,0.93,0.95],
    'ma':[0.01,0.1,0.5,1,2],
    'ms':[50,100,120,180,200],
}

params = {
    'thickness':[1],
    'ms':[100],
    'ma':[1],
    'g':[0.9],
    'n':[1.37],
    'n_air':1.,
    'xy_size':10,
    'voxel_space':0.01,
}
Rd = [];Tt =[]
Rd_int = [];Tt_int =[]
g=[];ms=[];ma=[]
thickness = []

for i in ParameterGrid(grid_params):
    print(i)
    params.update(i)
    for j in ['thickness','ms','ma','g']:
        params[j] = [params[j]]
        
    model = VoxelPlateModel(nPh = nPh)
    model.build(**params)
    model = model.start()
    res = model.getRdTtValues()
    Rd.append(res['Rd'])
    Tt.append(res['Tt'])
    g.append(i['g'])
    ma.append(i['ma'])
    ms.append(i['ms'])
    thickness.append(i['thickness'])
    res_int = model.get_result()
    Rd_,Tt_ = lightIntensityDist(res_int)
    Rd_int.append(Rd_)
    Tt_int.append(Tt_)
# Out:
# {'g': 0.9, 'ma': 0.01, 'ms': 50, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.768 [％]
# Calculation time: 0 minutes 1.605 seconds.
#
# Progress: 4.366 [％]
# Calculation time: 0 minutes 3.750 seconds.
#
# Progress: 26.657 [％]
# Calculation time: 0 minutes 8.077 seconds.
#
# Progress: 68.24 [％]
# Calculation time: 0 minutes 13.274 seconds.
#
# Progress: 90.602 [％]
# Calculation time: 0 minutes 17.175 seconds.
#
# Progress: 99.139 [％]
# Calculation time: 0 minutes 19.235 seconds.
#
# Progress: 99.991 [％]
# Calculation time: 0 minutes 20.136 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 20.753 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 21.821 seconds.
#
#
# ###### Finish ######
# Maximum step number: 823
# ######
# Mean Rd 0.254565
# Mean Tt 0.718146
#
# Calculation time: 0 minutes 23.261 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 50, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.578 [％]
# Calculation time: 0 minutes 1.647 seconds.
#
# Progress: 2.335 [％]
# Calculation time: 0 minutes 4.269 seconds.
#
# Progress: 13.433 [％]
# Calculation time: 0 minutes 8.905 seconds.
#
# Progress: 53.056 [％]
# Calculation time: 0 minutes 15.700 seconds.
#
# Progress: 83.014 [％]
# Calculation time: 0 minutes 21.805 seconds.
#
# Progress: 97.617 [％]
# Calculation time: 0 minutes 25.665 seconds.
#
# Progress: 99.946 [％]
# Calculation time: 0 minutes 27.079 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 27.839 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 29.055 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 31.349 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1473
# ######
# Mean Rd 0.306223
# Mean Tt 0.665538
#
# Calculation time: 0 minutes 33.339 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 50, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.545 [％]
# Calculation time: 0 minutes 1.481 seconds.
#
# Progress: 1.775 [％]
# Calculation time: 0 minutes 3.753 seconds.
#
# Progress: 5.071 [％]
# Calculation time: 0 minutes 8.320 seconds.
#
# Progress: 22.817 [％]
# Calculation time: 0 minutes 19.205 seconds.
#
# Progress: 61.629 [％]
# Calculation time: 0 minutes 31.994 seconds.
#
# Progress: 89.287 [％]
# Calculation time: 0 minutes 41.152 seconds.
#
# Progress: 99.164 [％]
# Calculation time: 0 minutes 45.543 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 46.983 seconds.
#
#
# ###### Finish ######
# Maximum step number: 411
# ######
# Mean Rd 0.409926
# Mean Tt 0.559338
#
# Calculation time: 0 minutes 47.667 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 100, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.525 [％]
# Calculation time: 0 minutes 0.877 seconds.
#
# Progress: 1.754 [％]
# Calculation time: 0 minutes 2.298 seconds.
#
# Progress: 4.837 [％]
# Calculation time: 0 minutes 5.008 seconds.
#
# Progress: 19.526 [％]
# Calculation time: 0 minutes 10.153 seconds.
#
# Progress: 57.75 [％]
# Calculation time: 0 minutes 17.035 seconds.
#
# Progress: 87.148 [％]
# Calculation time: 0 minutes 23.130 seconds.
#
# Progress: 98.823 [％]
# Calculation time: 0 minutes 26.487 seconds.
#
# Progress: 99.99 [％]
# Calculation time: 0 minutes 27.731 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 28.870 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 30.834 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 34.772 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 42.613 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 58.331 seconds.
#
#
# ###### Finish ######
# Maximum step number: 15771
# ######
# Mean Rd 0.428164
# Mean Tt 0.544026
#
# Calculation time: 1 minutes 27.288 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 100, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.539 [％]
# Calculation time: 0 minutes 0.873 seconds.
#
# Progress: 1.749 [％]
# Calculation time: 0 minutes 2.143 seconds.
#
# Progress: 4.604 [％]
# Calculation time: 0 minutes 4.861 seconds.
#
# Progress: 12.82 [％]
# Calculation time: 0 minutes 10.115 seconds.
#
# Progress: 43.371 [％]
# Calculation time: 0 minutes 18.422 seconds.
#
# Progress: 77.361 [％]
# Calculation time: 0 minutes 27.212 seconds.
#
# Progress: 96.356 [％]
# Calculation time: 0 minutes 33.064 seconds.
#
# Progress: 99.904 [％]
# Calculation time: 0 minutes 36.116 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 37.617 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 39.789 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 43.841 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 51.304 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 5.080 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 32.706 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 2 minutes 27.860 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 4 minutes 19.500 seconds.
#
#
# ###### Finish ######
# Maximum step number: 91862
# ######
# Mean Rd 0.489322
# Mean Tt 0.481836
#
# Calculation time: 5 minutes 48.081 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 100, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.531 [％]
# Calculation time: 0 minutes 0.883 seconds.
#
# Progress: 1.778 [％]
# Calculation time: 0 minutes 2.170 seconds.
#
# Progress: 4.611 [％]
# Calculation time: 0 minutes 4.926 seconds.
#
# Progress: 11.229 [％]
# Calculation time: 0 minutes 10.172 seconds.
#
# Progress: 25.713 [％]
# Calculation time: 0 minutes 19.578 seconds.
#
# Progress: 56.417 [％]
# Calculation time: 0 minutes 33.038 seconds.
#
# Progress: 85.133 [％]
# Calculation time: 0 minutes 45.929 seconds.
#
# Progress: 98.262 [％]
# Calculation time: 0 minutes 53.604 seconds.
#
# Progress: 99.975 [％]
# Calculation time: 0 minutes 56.330 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 58.416 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 2.104 seconds.
#
#
# ###### Finish ######
# Maximum step number: 2724
# ######
# Mean Rd 0.593677
# Mean Tt 0.374939
#
# Calculation time: 1 minutes 4.483 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 120, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.536 [％]
# Calculation time: 0 minutes 0.756 seconds.
#
# Progress: 1.766 [％]
# Calculation time: 0 minutes 1.934 seconds.
#
# Progress: 4.675 [％]
# Calculation time: 0 minutes 4.350 seconds.
#
# Progress: 13.56 [％]
# Calculation time: 0 minutes 9.058 seconds.
#
# Progress: 45.953 [％]
# Calculation time: 0 minutes 16.350 seconds.
#
# Progress: 79.344 [％]
# Calculation time: 0 minutes 23.675 seconds.
#
# Progress: 96.919 [％]
# Calculation time: 0 minutes 28.406 seconds.
#
# Progress: 99.933 [％]
# Calculation time: 0 minutes 30.258 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 31.216 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 32.539 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 35.107 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 40.240 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 50.459 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 10.988 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 49.960 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 3 minutes 3.053 seconds.
#
#
# ###### Finish ######
# Maximum step number: 110233
# ######
# Mean Rd 0.478402
# Mean Tt 0.493662
#
# Calculation time: 4 minutes 43.443 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 120, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.543 [％]
# Calculation time: 0 minutes 0.750 seconds.
#
# Progress: 1.762 [％]
# Calculation time: 0 minutes 1.901 seconds.
#
# Progress: 4.633 [％]
# Calculation time: 0 minutes 4.335 seconds.
#
# Progress: 11.489 [％]
# Calculation time: 0 minutes 8.996 seconds.
#
# Progress: 33.291 [％]
# Calculation time: 0 minutes 17.047 seconds.
#
# Progress: 68.004 [％]
# Calculation time: 0 minutes 26.803 seconds.
#
# Progress: 92.532 [％]
# Calculation time: 0 minutes 34.372 seconds.
#
# Progress: 99.576 [％]
# Calculation time: 0 minutes 37.905 seconds.
#
# Progress: 99.997 [％]
# Calculation time: 0 minutes 39.430 seconds.
#
#
# ###### Finish ######
# Maximum step number: 942
# ######
# Mean Rd 0.538417
# Mean Tt 0.432637
#
# Calculation time: 0 minutes 41.186 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 120, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.539 [％]
# Calculation time: 0 minutes 0.761 seconds.
# Progress: 1.748 [％]
# Calculation time: 0 minutes 1.897 seconds.
#
# Progress: 4.602 [％]
# Calculation time: 0 minutes 4.283 seconds.
#
# Progress: 11.178 [％]
# Calculation time: 0 minutes 9.062 seconds.
#
# Progress: 23.916 [％]
# Calculation time: 0 minutes 17.453 seconds.
#
# Progress: 48.32 [％]
# Calculation time: 0 minutes 30.435 seconds.
#
# Progress: 77.347 [％]
# Calculation time: 0 minutes 45.191 seconds.
#
# Progress: 95.658 [％]
# Calculation time: 0 minutes 56.063 seconds.
#
# Progress: 99.844 [％]
# Calculation time: 1 minutes 0.581 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 1 minutes 3.065 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 6.893 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 14.142 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 28.371 seconds.
#
#
# ###### Finish ######
# Maximum step number: 8397
# ######
# Mean Rd 0.637883
# Mean Tt 0.330607
#
# Calculation time: 1 minutes 29.097 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 180, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.528 [％]
# Calculation time: 0 minutes 0.598 seconds.
#
# Progress: 1.727 [％]
# Calculation time: 0 minutes 1.474 seconds.
#
# Progress: 4.604 [％]
# Calculation time: 0 minutes 3.403 seconds.
#
# Progress: 11.198 [％]
# Calculation time: 0 minutes 7.140 seconds.
#
# Progress: 26.551 [％]
# Calculation time: 0 minutes 13.650 seconds.
#
# Progress: 58.354 [％]
# Calculation time: 0 minutes 22.798 seconds.
#
# Progress: 86.663 [％]
# Calculation time: 0 minutes 31.303 seconds.
#
# Progress: 98.622 [％]
# Calculation time: 0 minutes 36.172 seconds.
#
# Progress: 99.983 [％]
# Calculation time: 0 minutes 38.028 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 39.456 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 41.923 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 46.783 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 56.699 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 16.367 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 56.202 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 3 minutes 14.893 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 5 minutes 52.155 seconds.
#
#
# ###### Finish ######
# Maximum step number: 165347
# ######
# Mean Rd 0.585801
# Mean Tt 0.386083
#
# Calculation time: 7 minutes 15.256 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 180, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.54 [％]
# Calculation time: 0 minutes 0.609 seconds.
#
# Progress: 1.761 [％]
# Calculation time: 0 minutes 1.485 seconds.
#
# Progress: 4.592 [％]
# Calculation time: 0 minutes 3.405 seconds.
#
# Progress: 11.169 [％]
# Calculation time: 0 minutes 7.095 seconds.
#
# Progress: 23.804 [％]
# Calculation time: 0 minutes 13.695 seconds.
#
# Progress: 48.033 [％]
# Calculation time: 0 minutes 23.931 seconds.
#
# Progress: 77.297 [％]
# Calculation time: 0 minutes 35.493 seconds.
#
# Progress: 95.669 [％]
# Calculation time: 0 minutes 44.097 seconds.
#
# Progress: 99.831 [％]
# Calculation time: 0 minutes 47.685 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 50.046 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 53.788 seconds.
#
#
# ###### Finish ######
# Maximum step number: 3362
# ######
# Mean Rd 0.638632
# Mean Tt 0.332221
#
# Calculation time: 0 minutes 58.531 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 180, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.535 [％]
# Calculation time: 0 minutes 0.619 seconds.
#
# Progress: 1.746 [％]
# Calculation time: 0 minutes 1.512 seconds.
#
# Progress: 4.534 [％]
# Calculation time: 0 minutes 3.409 seconds.
#
# Progress: 11.102 [％]
# Calculation time: 0 minutes 7.123 seconds.
#
# Progress: 23.523 [％]
# Calculation time: 0 minutes 13.776 seconds.
#
# Progress: 39.958 [％]
# Calculation time: 0 minutes 24.604 seconds.
#
# Progress: 61.455 [％]
# Calculation time: 0 minutes 40.123 seconds.
#
# Progress: 84.199 [％]
# Calculation time: 0 minutes 57.916 seconds.
#
# Progress: 97.328 [％]
# Calculation time: 1 minutes 11.436 seconds.
#
# Progress: 99.916 [％]
# Calculation time: 1 minutes 17.012 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 21.851 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 30.628 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 47.504 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 2 minutes 20.646 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 3 minutes 27.007 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 5 minutes 39.455 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 10 minutes 6.778 seconds.
#
#
# ###### Finish ######
# Maximum step number: 165347
# ######
# Mean Rd 0.723973
# Mean Tt 0.244341
#
# Calculation time: 12 minutes 26.027 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 200, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.53 [％]
# Calculation time: 0 minutes 0.610 seconds.
#
# Progress: 1.723 [％]
# Calculation time: 0 minutes 1.467 seconds.
#
# Progress: 4.575 [％]
# Calculation time: 0 minutes 3.362 seconds.
#
# Progress: 11.159 [％]
# Calculation time: 0 minutes 7.083 seconds.
#
# Progress: 24.765 [％]
# Calculation time: 0 minutes 13.800 seconds.
#
# Progress: 53.228 [％]
# Calculation time: 0 minutes 23.489 seconds.
#
# Progress: 82.477 [％]
# Calculation time: 0 minutes 33.444 seconds.
#
# Progress: 97.5 [％]
# Calculation time: 0 minutes 39.957 seconds.
#
# Progress: 99.953 [％]
# Calculation time: 0 minutes 42.604 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 44.659 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 48.298 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 55.495 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 9.841 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 38.502 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 2 minutes 35.786 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 4 minutes 30.470 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 8 minutes 22.399 seconds.
#
#
# ###### Finish ######
# Maximum step number: 183718
# ######
# Mean Rd 0.612831
# Mean Tt 0.359016
#
# Calculation time: 11 minutes 28.249 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 200, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.53 [％]
# Calculation time: 0 minutes 0.603 seconds.
#
# Progress: 1.721 [％]
# Calculation time: 0 minutes 1.462 seconds.
#
# Progress: 4.571 [％]
# Calculation time: 0 minutes 3.374 seconds.
#
# Progress: 11.131 [％]
# Calculation time: 0 minutes 7.036 seconds.
#
# Progress: 23.583 [％]
# Calculation time: 0 minutes 13.698 seconds.
#
# Progress: 44.694 [％]
# Calculation time: 0 minutes 24.172 seconds.
#
# Progress: 72.787 [％]
# Calculation time: 0 minutes 37.083 seconds.
#
# Progress: 93.402 [％]
# Calculation time: 0 minutes 47.844 seconds.
#
# Progress: 99.605 [％]
# Calculation time: 0 minutes 53.156 seconds.
#
# Progress: 99.997 [％]
# Calculation time: 0 minutes 55.735 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 59.797 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 7.561 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 22.784 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 53.208 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 2 minutes 54.005 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 4 minutes 57.135 seconds.
#
#
# ###### Finish ######
# Maximum step number: 107433
# ######
# Mean Rd 0.663968
# Mean Tt 0.306853
#
# Calculation time: 7 minutes 32.692 seconds.
# {'g': 0.9, 'ma': 0.01, 'ms': 200, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.536 [％]
# Calculation time: 0 minutes 0.601 seconds.
#
# Progress: 1.763 [％]
# Calculation time: 0 minutes 1.470 seconds.
#
# Progress: 4.585 [％]
# Calculation time: 0 minutes 3.365 seconds.
#
# Progress: 11.248 [％]
# Calculation time: 0 minutes 7.081 seconds.
#
# Progress: 23.588 [％]
# Calculation time: 0 minutes 13.698 seconds.
#
# Progress: 39.688 [％]
# Calculation time: 0 minutes 24.458 seconds.
#
# Progress: 58.67 [％]
# Calculation time: 0 minutes 40.390 seconds.
#
# Progress: 80.494 [％]
# Calculation time: 0 minutes 59.824 seconds.
#
# Progress: 95.651 [％]
# Calculation time: 1 minutes 15.963 seconds.
#
# Progress: 99.776 [％]
# Calculation time: 1 minutes 23.463 seconds.
#
# Progress: 99.997 [％]
# Calculation time: 1 minutes 28.283 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 36.234 seconds.
# Progress: 100.0 [％]
# Calculation time: 1 minutes 51.476 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 2 minutes 21.873 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 3 minutes 22.490 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 5 minutes 24.017 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 9 minutes 28.597 seconds.
#
#
# ###### Finish ######
# Maximum step number: 183718
# ######
# Mean Rd 0.744314
# Mean Tt 0.223952
#
# Calculation time: 12 minutes 43.913 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 50, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.773 [％]
# Calculation time: 0 minutes 1.528 seconds.
#
# Progress: 4.336 [％]
# Calculation time: 0 minutes 3.836 seconds.
#
# Progress: 26.575 [％]
# Calculation time: 0 minutes 8.174 seconds.
#
# Progress: 68.177 [％]
# Calculation time: 0 minutes 13.184 seconds.
#
# Progress: 90.51 [％]
# Calculation time: 0 minutes 17.266 seconds.
#
# Progress: 99.112 [％]
# Calculation time: 0 minutes 19.428 seconds.
#
# Progress: 99.991 [％]
# Calculation time: 0 minutes 20.294 seconds.
#
#
# ###### Finish ######
# Maximum step number: 227
# ######
# Mean Rd 0.245977
# Mean Tt 0.701073
#
# Calculation time: 0 minutes 20.784 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 50, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.593 [％]
# Calculation time: 0 minutes 1.543 seconds.
#
# Progress: 2.372 [％]
# Calculation time: 0 minutes 3.896 seconds.
#
# Progress: 13.39 [％]
# Calculation time: 0 minutes 8.538 seconds.
#
# Progress: 52.774 [％]
# Calculation time: 0 minutes 15.447 seconds.
#
# Progress: 82.945 [％]
# Calculation time: 0 minutes 21.631 seconds.
#
# Progress: 97.567 [％]
# Calculation time: 0 minutes 25.535 seconds.
#
# Progress: 99.947 [％]
# Calculation time: 0 minutes 27.013 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 27.759 seconds.
#
#
# ###### Finish ######
# Maximum step number: 504
# ######
# Mean Rd 0.293834
# Mean Tt 0.644143
#
# Calculation time: 0 minutes 28.846 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 50, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.55 [％]
# Calculation time: 0 minutes 1.556 seconds.
#
# Progress: 1.797 [％]
# Calculation time: 0 minutes 3.854 seconds.
#
# Progress: 5.12 [％]
# Calculation time: 0 minutes 8.632 seconds.
#
# Progress: 22.852 [％]
# Calculation time: 0 minutes 17.670 seconds.
#
# Progress: 61.6 [％]
# Calculation time: 0 minutes 29.241 seconds.
#
# Progress: 89.276 [％]
# Calculation time: 0 minutes 38.760 seconds.
#
# Progress: 99.174 [％]
# Calculation time: 0 minutes 43.368 seconds.
#
# Progress: 99.995 [％]
# Calculation time: 0 minutes 44.946 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 46.177 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 48.459 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1136
# ######
# Mean Rd 0.387085
# Mean Tt 0.527792
#
# Calculation time: 0 minutes 48.968 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 100, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.53 [％]
# Calculation time: 0 minutes 0.913 seconds.
#
# Progress: 1.758 [％]
# Calculation time: 0 minutes 2.276 seconds.
#
# Progress: 4.848 [％]
# Calculation time: 0 minutes 5.160 seconds.
#
# Progress: 19.495 [％]
# Calculation time: 0 minutes 10.608 seconds.
#
# Progress: 57.616 [％]
# Calculation time: 0 minutes 18.036 seconds.
#
# Progress: 87.084 [％]
# Calculation time: 0 minutes 24.553 seconds.
#
# Progress: 98.811 [％]
# Calculation time: 0 minutes 27.954 seconds.
#
# Progress: 99.987 [％]
# Calculation time: 0 minutes 29.268 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 30.376 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 32.393 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 36.319 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 44.247 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 0.036 seconds.
#
#
# ###### Finish ######
# Maximum step number: 8824
# ######
# Mean Rd 0.415989
# Mean Tt 0.526048
#
# Calculation time: 1 minutes 2.523 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 100, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.54 [％]
# Calculation time: 0 minutes 0.890 seconds.
#
# Progress: 1.792 [％]
# Calculation time: 0 minutes 2.220 seconds.
#
# Progress: 4.643 [％]
# Calculation time: 0 minutes 5.026 seconds.
#
# Progress: 12.828 [％]
# Calculation time: 0 minutes 10.558 seconds.
#
# Progress: 43.364 [％]
# Calculation time: 0 minutes 19.394 seconds.
#
# Progress: 77.403 [％]
# Calculation time: 0 minutes 28.684 seconds.
#
# Progress: 96.331 [％]
# Calculation time: 0 minutes 34.837 seconds.
#
# Progress: 99.906 [％]
# Calculation time: 0 minutes 37.271 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 38.673 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 40.877 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 45.335 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 53.907 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 11.029 seconds.
#
#
# ###### Finish ######
# Maximum step number: 9191
# ######
# Mean Rd 0.471173
# Mean Tt 0.461217
#
# Calculation time: 1 minutes 15.203 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 100, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.559 [％]
# Calculation time: 0 minutes 0.892 seconds.
#
# Progress: 1.769 [％]
# Calculation time: 0 minutes 2.236 seconds.
#
# Progress: 4.661 [％]
# Calculation time: 0 minutes 5.099 seconds.
#
# Progress: 11.211 [％]
# Calculation time: 0 minutes 10.624 seconds.
#
# Progress: 25.765 [％]
# Calculation time: 0 minutes 20.648 seconds.
#
# Progress: 56.283 [％]
# Calculation time: 0 minutes 36.932 seconds.
#
# Progress: 85.005 [％]
# Calculation time: 0 minutes 51.362 seconds.
#
# Progress: 98.206 [％]
# Calculation time: 0 minutes 59.646 seconds.
#
# Progress: 99.976 [％]
# Calculation time: 1 minutes 2.570 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 4.771 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 8.668 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 16.134 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 31.056 seconds.
#
#
# ###### Finish ######
# Maximum step number: 9191
# ######
# Mean Rd 0.562832
# Mean Tt 0.346205
#
# Calculation time: 1 minutes 34.699 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 120, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.554 [％]
# Calculation time: 0 minutes 0.796 seconds.
#
# Progress: 1.783 [％]
# Calculation time: 0 minutes 2.018 seconds.
#
# Progress: 4.671 [％]
# Calculation time: 0 minutes 4.561 seconds.
#
# Progress: 13.582 [％]
# Calculation time: 0 minutes 9.526 seconds.
#
# Progress: 46.063 [％]
# Calculation time: 0 minutes 17.253 seconds.
#
# Progress: 79.415 [％]
# Calculation time: 0 minutes 24.969 seconds.
#
# Progress: 96.964 [％]
# Calculation time: 0 minutes 29.847 seconds.
#
# Progress: 99.928 [％]
# Calculation time: 0 minutes 31.821 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 33.081 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 35.225 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 39.457 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 47.782 seconds.
#
#
# ###### Finish ######
# Maximum step number: 5770
# ######
# Mean Rd 0.464398
# Mean Tt 0.476633
#
# Calculation time: 0 minutes 54.625 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 120, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.534 [％]
# Calculation time: 0 minutes 0.808 seconds.
#
# Progress: 1.748 [％]
# Calculation time: 0 minutes 1.992 seconds.
#
# Progress: 4.577 [％]
# Calculation time: 0 minutes 4.533 seconds.
#
# Progress: 11.407 [％]
# Calculation time: 0 minutes 9.487 seconds.
#
# Progress: 33.235 [％]
# Calculation time: 0 minutes 17.986 seconds.
#
# Progress: 68.008 [％]
# Calculation time: 0 minutes 28.283 seconds.
#
# Progress: 92.463 [％]
# Calculation time: 0 minutes 36.427 seconds.
#
# Progress: 99.58 [％]
# Calculation time: 0 minutes 40.239 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 41.915 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 43.994 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 47.913 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 55.733 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 11.433 seconds.
#
#
# ###### Finish ######
# Maximum step number: 11028
# ######
# Mean Rd 0.518964
# Mean Tt 0.412404
#
# Calculation time: 1 minutes 22.291 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 120, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
# Progress: 0.537 [％]
# Calculation time: 0 minutes 0.780 seconds.
#
# Progress: 1.741 [％]
# Calculation time: 0 minutes 1.971 seconds.
#
# Progress: 4.631 [％]
# Calculation time: 0 minutes 4.470 seconds.
#
# Progress: 11.206 [％]
# Calculation time: 0 minutes 9.436 seconds.
#
# Progress: 23.886 [％]
# Calculation time: 0 minutes 18.275 seconds.
#
# Progress: 48.196 [％]
# Calculation time: 0 minutes 32.074 seconds.
#
# Progress: 77.374 [％]
# Calculation time: 0 minutes 47.828 seconds.
#
# Progress: 95.661 [％]
# Calculation time: 0 minutes 59.357 seconds.
#
# Progress: 99.838 [％]
# Calculation time: 1 minutes 4.285 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 6.876 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1961
# ######
# Mean Rd 0.604296
# Mean Tt 0.303961
#
# Calculation time: 1 minutes 10.392 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 180, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.549 [％]
# Calculation time: 0 minutes 0.628 seconds.
#
# Progress: 1.758 [％]
# Calculation time: 0 minutes 1.547 seconds.
#
# Progress: 4.623 [％]
# Calculation time: 0 minutes 3.573 seconds.
#
# Progress: 11.209 [％]
# Calculation time: 0 minutes 7.549 seconds.
#
# Progress: 26.578 [％]
# Calculation time: 0 minutes 14.506 seconds.
#
# Progress: 58.376 [％]
# Calculation time: 0 minutes 24.040 seconds.
#
# Progress: 86.705 [％]
# Calculation time: 0 minutes 33.076 seconds.
#
# Progress: 98.603 [％]
# Calculation time: 0 minutes 38.348 seconds.
#
# Progress: 99.983 [％]
# Calculation time: 0 minutes 40.347 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 42.508 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 46.414 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 54.043 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 9.280 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 39.810 seconds.
#
#
# ###### Finish ######
# Maximum step number: 16539
# ######
# Mean Rd 0.568063
# Mean Tt 0.371256
#
# Calculation time: 1 minutes 40.389 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 180, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.558 [％]
# Calculation time: 0 minutes 0.633 seconds.
#
# Progress: 1.756 [％]
# Calculation time: 0 minutes 1.630 seconds.
#
# Progress: 4.603 [％]
# Calculation time: 0 minutes 3.649 seconds.
#
# Progress: 11.155 [％]
# Calculation time: 0 minutes 7.641 seconds.
#
# Progress: 23.814 [％]
# Calculation time: 0 minutes 14.585 seconds.
#
# Progress: 48.24 [％]
# Calculation time: 0 minutes 25.428 seconds.
#
# Progress: 77.402 [％]
# Calculation time: 0 minutes 37.671 seconds.
#
# Progress: 95.62 [％]
# Calculation time: 0 minutes 46.873 seconds.
#
# Progress: 99.829 [％]
# Calculation time: 0 minutes 50.884 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 53.365 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 57.370 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 5.239 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 20.930 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 52.354 seconds.
#
#
# ###### Finish ######
# Maximum step number: 16539
# ######
# Mean Rd 0.616822
# Mean Tt 0.312895
#
# Calculation time: 1 minutes 52.952 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 180, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.536 [％]
# Calculation time: 0 minutes 0.643 seconds.
#
# Progress: 1.764 [％]
# Calculation time: 0 minutes 1.572 seconds.
#
# Progress: 4.623 [％]
# Calculation time: 0 minutes 3.646 seconds.
#
# Progress: 11.209 [％]
# Calculation time: 0 minutes 7.590 seconds.
#
# Progress: 23.526 [％]
# Calculation time: 0 minutes 14.572 seconds.
#
# Progress: 39.97 [％]
# Calculation time: 0 minutes 25.967 seconds.
#
# Progress: 61.471 [％]
# Calculation time: 0 minutes 42.431 seconds.
#
# Progress: 84.203 [％]
# Calculation time: 1 minutes 1.025 seconds.
#
# Progress: 97.333 [％]
# Calculation time: 1 minutes 14.416 seconds.
#
# Progress: 99.921 [％]
# Calculation time: 1 minutes 20.088 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 24.745 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 32.774 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 48.473 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 2 minutes 20.906 seconds.
#
#
# ###### Finish ######
# Maximum step number: 16539
# ######
# Mean Rd 0.688534
# Mean Tt 0.218800
#
# Calculation time: 2 minutes 21.493 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 200, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.541 [％]
# Calculation time: 0 minutes 0.605 seconds.
#
# Progress: 1.754 [％]
# Calculation time: 0 minutes 1.477 seconds.
#
# Progress: 4.611 [％]
# Calculation time: 0 minutes 3.370 seconds.
#
# Progress: 11.177 [％]
# Calculation time: 0 minutes 7.086 seconds.
#
# Progress: 24.735 [％]
# Calculation time: 0 minutes 13.766 seconds.
#
# Progress: 53.241 [％]
# Calculation time: 0 minutes 23.500 seconds.
#
# Progress: 82.379 [％]
# Calculation time: 0 minutes 33.580 seconds.
#
# Progress: 97.49 [％]
# Calculation time: 0 minutes 40.066 seconds.
#
# Progress: 99.948 [％]
# Calculation time: 0 minutes 42.694 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 44.899 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 48.960 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 56.664 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 11.867 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 42.258 seconds.
#
#
# ###### Finish ######
# Maximum step number: 18376
# ######
# Mean Rd 0.593861
# Mean Tt 0.345051
#
# Calculation time: 1 minutes 49.622 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 200, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.536 [％]
# Calculation time: 0 minutes 0.614 seconds.
#
# Progress: 1.779 [％]
# Calculation time: 0 minutes 1.488 seconds.
#
# Progress: 4.662 [％]
# Calculation time: 0 minutes 3.382 seconds.
#
# Progress: 11.217 [％]
# Calculation time: 0 minutes 7.062 seconds.
#
# Progress: 23.639 [％]
# Calculation time: 0 minutes 13.649 seconds.
#
# Progress: 44.696 [％]
# Calculation time: 0 minutes 24.108 seconds.
#
# Progress: 72.74 [％]
# Calculation time: 0 minutes 37.085 seconds.
#
# Progress: 93.393 [％]
# Calculation time: 0 minutes 47.964 seconds.
#
# Progress: 99.595 [％]
# Calculation time: 0 minutes 53.206 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 56.034 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 0.376 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 8.739 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 25.246 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 58.344 seconds.
#
#
# ###### Finish ######
# Maximum step number: 18376
# ######
# Mean Rd 0.639763
# Mean Tt 0.289699
#
# Calculation time: 2 minutes 6.375 seconds.
# {'g': 0.9, 'ma': 0.1, 'ms': 200, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.529 [％]
# Calculation time: 0 minutes 0.610 seconds.
#
# Progress: 1.757 [％]
# Calculation time: 0 minutes 1.483 seconds.
#
# Progress: 4.632 [％]
# Calculation time: 0 minutes 3.367 seconds.
#
# Progress: 11.222 [％]
# Calculation time: 0 minutes 7.014 seconds.
#
# Progress: 23.638 [％]
# Calculation time: 0 minutes 13.585 seconds.
#
# Progress: 39.626 [％]
# Calculation time: 0 minutes 24.381 seconds.
#
# Progress: 58.63 [％]
# Calculation time: 0 minutes 40.312 seconds.
#
# Progress: 80.492 [％]
# Calculation time: 0 minutes 59.747 seconds.
#
# Progress: 95.672 [％]
# Calculation time: 1 minutes 15.682 seconds.
#
# Progress: 99.78 [％]
# Calculation time: 1 minutes 23.161 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 1 minutes 28.180 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 36.464 seconds.
#
#
# ###### Finish ######
# Maximum step number: 6534
# ######
# Mean Rd 0.707510
# Mean Tt 0.199629
#
# Calculation time: 1 minutes 46.013 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 50, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.802 [％]
# Calculation time: 0 minutes 1.507 seconds.
#
# Progress: 4.274 [％]
# Calculation time: 0 minutes 3.802 seconds.
#
# Progress: 25.919 [％]
# Calculation time: 0 minutes 8.150 seconds.
#
# Progress: 67.598 [％]
# Calculation time: 0 minutes 13.265 seconds.
#
# Progress: 90.346 [％]
# Calculation time: 0 minutes 17.391 seconds.
#
# Progress: 99.099 [％]
# Calculation time: 0 minutes 19.641 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 20.530 seconds.
# Progress: 100.0 [％]
# Calculation time: 0 minutes 21.129 seconds.
#
#
# ###### Finish ######
# Maximum step number: 325
# ######
# Mean Rd 0.212936
# Mean Tt 0.631845
#
# Calculation time: 0 minutes 21.420 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 50, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.578 [％]
# Calculation time: 0 minutes 1.539 seconds.
#
# Progress: 2.294 [％]
# Calculation time: 0 minutes 3.825 seconds.
#
# Progress: 13.0 [％]
# Calculation time: 0 minutes 8.536 seconds.
#
# Progress: 52.21 [％]
# Calculation time: 0 minutes 15.424 seconds.
#
# Progress: 82.598 [％]
# Calculation time: 0 minutes 21.635 seconds.
#
# Progress: 97.468 [％]
# Calculation time: 0 minutes 25.573 seconds.
#
# Progress: 99.944 [％]
# Calculation time: 0 minutes 27.125 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 27.858 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 28.917 seconds.
#
#
# ###### Finish ######
# Maximum step number: 531
# ######
# Mean Rd 0.246770
# Mean Tt 0.560682
#
# Calculation time: 0 minutes 29.004 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 50, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.535 [％]
# Calculation time: 0 minutes 1.508 seconds.
#
# Progress: 1.758 [％]
# Calculation time: 0 minutes 3.785 seconds.
#
# Progress: 5.05 [％]
# Calculation time: 0 minutes 8.571 seconds.
#
# Progress: 22.411 [％]
# Calculation time: 0 minutes 17.523 seconds.
#
# Progress: 61.087 [％]
# Calculation time: 0 minutes 29.057 seconds.
#
# Progress: 89.041 [％]
# Calculation time: 0 minutes 38.754 seconds.
#
# Progress: 99.113 [％]
# Calculation time: 0 minutes 43.535 seconds.
#
# Progress: 99.994 [％]
# Calculation time: 0 minutes 45.110 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 46.278 seconds.
#
#
# ###### Finish ######
# Maximum step number: 924
# ######
# Mean Rd 0.304831
# Mean Tt 0.416221
#
# Calculation time: 0 minutes 48.012 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 100, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.538 [％]
# Calculation time: 0 minutes 0.908 seconds.
#
# Progress: 1.749 [％]
# Calculation time: 0 minutes 2.263 seconds.
#
# Progress: 4.828 [％]
# Calculation time: 0 minutes 5.138 seconds.
#
# Progress: 19.298 [％]
# Calculation time: 0 minutes 10.590 seconds.
#
# Progress: 57.286 [％]
# Calculation time: 0 minutes 17.990 seconds.
#
# Progress: 86.919 [％]
# Calculation time: 0 minutes 24.476 seconds.
#
# Progress: 98.783 [％]
# Calculation time: 0 minutes 28.007 seconds.
#
# Progress: 99.988 [％]
# Calculation time: 0 minutes 29.344 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 30.461 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 32.452 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1842
# ######
# Mean Rd 0.363739
# Mean Tt 0.460119
#
# Calculation time: 0 minutes 35.667 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 100, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.541 [％]
# Calculation time: 0 minutes 0.889 seconds.
#
# Progress: 1.777 [％]
# Calculation time: 0 minutes 2.236 seconds.
#
# Progress: 4.649 [％]
# Calculation time: 0 minutes 5.089 seconds.
#
# Progress: 12.749 [％]
# Calculation time: 0 minutes 10.642 seconds.
#
# Progress: 42.998 [％]
# Calculation time: 0 minutes 19.568 seconds.
#
# Progress: 77.143 [％]
# Calculation time: 0 minutes 28.868 seconds.
#
# Progress: 96.243 [％]
# Calculation time: 0 minutes 35.265 seconds.
#
# Progress: 99.893 [％]
# Calculation time: 0 minutes 37.701 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 39.005 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 41.043 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1842
# ######
# Mean Rd 0.403165
# Mean Tt 0.382696
#
# Calculation time: 0 minutes 44.240 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 100, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.542 [％]
# Calculation time: 0 minutes 0.903 seconds.
#
# Progress: 1.779 [％]
# Calculation time: 0 minutes 2.229 seconds.
#
# Progress: 4.659 [％]
# Calculation time: 0 minutes 5.099 seconds.
#
# Progress: 11.188 [％]
# Calculation time: 0 minutes 10.688 seconds.
#
# Progress: 25.656 [％]
# Calculation time: 0 minutes 20.638 seconds.
#
# Progress: 56.018 [％]
# Calculation time: 0 minutes 34.727 seconds.
#
# Progress: 84.745 [％]
# Calculation time: 0 minutes 50.691 seconds.
#
# Progress: 98.175 [％]
# Calculation time: 1 minutes 1.209 seconds.
#
# Progress: 99.973 [％]
# Calculation time: 1 minutes 4.313 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 6.537 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1842
# ######
# Mean Rd 0.456086
# Mean Tt 0.249446
#
# Calculation time: 1 minutes 9.517 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 120, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.54 [％]
# Calculation time: 0 minutes 0.811 seconds.
#
# Progress: 1.74 [％]
# Calculation time: 0 minutes 2.009 seconds.
#
# Progress: 4.641 [％]
# Calculation time: 0 minutes 4.558 seconds.
#
# Progress: 13.45 [％]
# Calculation time: 0 minutes 9.447 seconds.
#
# Progress: 45.656 [％]
# Calculation time: 0 minutes 17.116 seconds.
#
# Progress: 79.121 [％]
# Calculation time: 0 minutes 24.906 seconds.
#
# Progress: 96.875 [％]
# Calculation time: 0 minutes 29.943 seconds.
#
# Progress: 99.931 [％]
# Calculation time: 0 minutes 31.968 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 32.916 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 34.373 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 37.224 seconds.
#
#
# ###### Finish ######
# Maximum step number: 2210
# ######
# Mean Rd 0.406828
# Mean Tt 0.412715
#
# Calculation time: 0 minutes 37.683 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 120, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.54 [％]
# Calculation time: 0 minutes 0.787 seconds.
#
# Progress: 1.764 [％]
# Calculation time: 0 minutes 1.983 seconds.
#
# Progress: 4.575 [％]
# Calculation time: 0 minutes 4.487 seconds.
#
# Progress: 11.399 [％]
# Calculation time: 0 minutes 9.414 seconds.
#
# Progress: 32.993 [％]
# Calculation time: 0 minutes 17.923 seconds.
#
# Progress: 67.741 [％]
# Calculation time: 0 minutes 28.261 seconds.
#
# Progress: 92.406 [％]
# Calculation time: 0 minutes 36.533 seconds.
#
# Progress: 99.582 [％]
# Calculation time: 0 minutes 40.454 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 42.076 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 44.146 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 48.114 seconds.
#
#
# ###### Finish ######
# Maximum step number: 2210
# ######
# Mean Rd 0.444416
# Mean Tt 0.338381
#
# Calculation time: 0 minutes 48.733 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 120, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.537 [％]
# Calculation time: 0 minutes 0.794 seconds.
#
# Progress: 1.772 [％]
# Calculation time: 0 minutes 1.970 seconds.
#
# Progress: 4.645 [％]
# Calculation time: 0 minutes 4.446 seconds.
#
# Progress: 11.201 [％]
# Calculation time: 0 minutes 9.360 seconds.
#
# Progress: 23.843 [％]
# Calculation time: 0 minutes 18.203 seconds.
#
# Progress: 48.071 [％]
# Calculation time: 0 minutes 33.217 seconds.
#
# Progress: 77.227 [％]
# Calculation time: 0 minutes 48.781 seconds.
#
# Progress: 95.59 [％]
# Calculation time: 1 minutes 0.404 seconds.
#
# Progress: 99.818 [％]
# Calculation time: 1 minutes 5.360 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 8.001 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 12.181 seconds.
#
#
# ###### Finish ######
# Maximum step number: 2763
# ######
# Mean Rd 0.492491
# Mean Tt 0.213251
#
# Calculation time: 1 minutes 14.980 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 180, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.529 [％]
# Calculation time: 0 minutes 0.631 seconds.
#
# Progress: 1.768 [％]
# Calculation time: 0 minutes 1.551 seconds.
#
# Progress: 4.648 [％]
# Calculation time: 0 minutes 3.553 seconds.
#
# Progress: 11.217 [％]
# Calculation time: 0 minutes 7.425 seconds.
#
# Progress: 26.611 [％]
# Calculation time: 0 minutes 14.295 seconds.
#
# Progress: 58.139 [％]
# Calculation time: 0 minutes 23.902 seconds.
#
# Progress: 86.486 [％]
# Calculation time: 0 minutes 32.911 seconds.
#
# Progress: 98.578 [％]
# Calculation time: 0 minutes 38.208 seconds.
#
# Progress: 99.978 [％]
# Calculation time: 0 minutes 40.319 seconds.
# Progress: 100.0 [％]
# Calculation time: 0 minutes 42.458 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 46.487 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 54.393 seconds.
#
#
# ###### Finish ######
# Maximum step number: 4142
# ######
# Mean Rd 0.503761
# Mean Tt 0.310237
#
# Calculation time: 0 minutes 54.573 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 180, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.538 [％]
# Calculation time: 0 minutes 0.695 seconds.
#
# Progress: 1.756 [％]
# Calculation time: 0 minutes 1.629 seconds.
#
# Progress: 4.657 [％]
# Calculation time: 0 minutes 3.631 seconds.
#
# Progress: 11.25 [％]
# Calculation time: 0 minutes 7.523 seconds.
#
# Progress: 23.855 [％]
# Calculation time: 0 minutes 14.537 seconds.
#
# Progress: 48.059 [％]
# Calculation time: 0 minutes 25.311 seconds.
#
# Progress: 77.187 [％]
# Calculation time: 0 minutes 37.514 seconds.
#
# Progress: 95.643 [％]
# Calculation time: 0 minutes 46.645 seconds.
#
# Progress: 99.836 [％]
# Calculation time: 0 minutes 50.648 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 53.115 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 57.056 seconds.
#
#
# ###### Finish ######
# Maximum step number: 3312
# ######
# Mean Rd 0.533977
# Mean Tt 0.245411
#
# Calculation time: 1 minutes 1.759 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 180, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.538 [％]
# Calculation time: 0 minutes 0.647 seconds.
#
# Progress: 1.753 [％]
# Calculation time: 0 minutes 1.601 seconds.
#
# Progress: 4.64 [％]
# Calculation time: 0 minutes 3.580 seconds.
#
# Progress: 11.216 [％]
# Calculation time: 0 minutes 7.438 seconds.
#
# Progress: 23.498 [％]
# Calculation time: 0 minutes 14.419 seconds.
#
# Progress: 39.882 [％]
# Calculation time: 0 minutes 25.761 seconds.
#
# Progress: 61.349 [％]
# Calculation time: 0 minutes 42.221 seconds.
#
# Progress: 84.077 [％]
# Calculation time: 1 minutes 0.635 seconds.
#
# Progress: 97.32 [％]
# Calculation time: 1 minutes 14.002 seconds.
#
# Progress: 99.925 [％]
# Calculation time: 1 minutes 19.606 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 1 minutes 24.541 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 33.142 seconds.
#
#
# ###### Finish ######
# Maximum step number: 4142
# ######
# Mean Rd 0.570222
# Mean Tt 0.140632
#
# Calculation time: 1 minutes 33.331 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 200, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.538 [％]
# Calculation time: 0 minutes 0.602 seconds.
#
# Progress: 1.727 [％]
# Calculation time: 0 minutes 1.458 seconds.
#
# Progress: 4.588 [％]
# Calculation time: 0 minutes 3.313 seconds.
#
# Progress: 11.184 [％]
# Calculation time: 0 minutes 6.952 seconds.
#
# Progress: 24.678 [％]
# Calculation time: 0 minutes 13.639 seconds.
#
# Progress: 53.055 [％]
# Calculation time: 0 minutes 23.328 seconds.
#
# Progress: 82.327 [％]
# Calculation time: 0 minutes 33.364 seconds.
#
# Progress: 97.491 [％]
# Calculation time: 0 minutes 39.884 seconds.
#
# Progress: 99.951 [％]
# Calculation time: 0 minutes 42.466 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 44.690 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 48.639 seconds.
#
#
# ###### Finish ######
# Maximum step number: 3679
# ######
# Mean Rd 0.527081
# Mean Tt 0.286104
#
# Calculation time: 0 minutes 54.724 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 200, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.541 [％]
# Calculation time: 0 minutes 0.598 seconds.
#
# Progress: 1.745 [％]
# Calculation time: 0 minutes 1.455 seconds.
#
# Progress: 4.6 [％]
# Calculation time: 0 minutes 3.321 seconds.
#
# Progress: 11.187 [％]
# Calculation time: 0 minutes 6.966 seconds.
#
# Progress: 23.562 [％]
# Calculation time: 0 minutes 13.602 seconds.
#
# Progress: 44.569 [％]
# Calculation time: 0 minutes 24.038 seconds.
#
# Progress: 72.636 [％]
# Calculation time: 0 minutes 36.933 seconds.
#
# Progress: 93.318 [％]
# Calculation time: 0 minutes 47.754 seconds.
#
# Progress: 99.592 [％]
# Calculation time: 0 minutes 53.065 seconds.
#
# Progress: 99.997 [％]
# Calculation time: 0 minutes 55.500 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 58.414 seconds.
#
#
# ###### Finish ######
# Maximum step number: 3679
# ######
# Mean Rd 0.556751
# Mean Tt 0.222542
#
# Calculation time: 1 minutes 2.733 seconds.
# {'g': 0.9, 'ma': 0.5, 'ms': 200, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.531 [％]
# Calculation time: 0 minutes 0.600 seconds.
#
# Progress: 1.727 [％]
# Calculation time: 0 minutes 1.456 seconds.
#
# Progress: 4.566 [％]
# Calculation time: 0 minutes 3.316 seconds.
#
# Progress: 11.161 [％]
# Calculation time: 0 minutes 6.915 seconds.
#
# Progress: 23.46 [％]
# Calculation time: 0 minutes 13.505 seconds.
#
# Progress: 39.587 [％]
# Calculation time: 0 minutes 24.309 seconds.
#
# Progress: 58.648 [％]
# Calculation time: 0 minutes 40.314 seconds.
#
# Progress: 80.489 [％]
# Calculation time: 0 minutes 59.823 seconds.
#
# Progress: 95.628 [％]
# Calculation time: 1 minutes 15.924 seconds.
#
# Progress: 99.77 [％]
# Calculation time: 1 minutes 23.376 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 1 minutes 28.728 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 37.371 seconds.
#
#
# ###### Finish ######
# Maximum step number: 4602
# ######
# Mean Rd 0.589335
# Mean Tt 0.124064
#
# Calculation time: 1 minutes 39.322 seconds.
# {'g': 0.9, 'ma': 1, 'ms': 50, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.767 [％]
# Calculation time: 0 minutes 1.801 seconds.
#
# Progress: 4.129 [％]
# Calculation time: 0 minutes 4.201 seconds.
#
# Progress: 25.371 [％]
# Calculation time: 0 minutes 8.541 seconds.
#
# Progress: 67.023 [％]
# Calculation time: 0 minutes 13.782 seconds.
#
# Progress: 90.052 [％]
# Calculation time: 0 minutes 17.902 seconds.
#
# Progress: 99.068 [％]
# Calculation time: 0 minutes 20.156 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 21.026 seconds.
#
#
# ###### Finish ######
# Maximum step number: 254
# ######
# Mean Rd 0.179357
# Mean Tt 0.559557
#
# Calculation time: 0 minutes 21.491 seconds.
# {'g': 0.9, 'ma': 1, 'ms': 50, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.569 [％]
# Calculation time: 0 minutes 1.528 seconds.
#
# Progress: 2.261 [％]
# Calculation time: 0 minutes 3.756 seconds.
#
# Progress: 12.623 [％]
# Calculation time: 0 minutes 8.409 seconds.
#
# Progress: 51.516 [％]
# Calculation time: 0 minutes 15.393 seconds.
#
# Progress: 82.287 [％]
# Calculation time: 0 minutes 21.681 seconds.
#
# Progress: 97.386 [％]
# Calculation time: 0 minutes 25.677 seconds.
#
# Progress: 99.946 [％]
# Calculation time: 0 minutes 27.207 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 27.987 seconds.
#
#
# ...
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.259 [％]
# Calculation time: 0 minutes 0.599 seconds.
#
# Progress: 0.802 [％]
# Calculation time: 0 minutes 1.436 seconds.
#
# Progress: 2.01 [％]
# Calculation time: 0 minutes 3.263 seconds.
#
# Progress: 4.875 [％]
# Calculation time: 0 minutes 6.969 seconds.
#
# Progress: 11.325 [％]
# Calculation time: 0 minutes 14.129 seconds.
#
# Progress: 27.291 [％]
# Calculation time: 0 minutes 26.800 seconds.
#
# Progress: 61.372 [％]
# Calculation time: 0 minutes 43.637 seconds.
#
# Progress: 88.818 [％]
# Calculation time: 0 minutes 58.640 seconds.
#
# Progress: 99.06 [％]
# Calculation time: 1 minutes 6.566 seconds.
#
# Progress: 99.991 [％]
# Calculation time: 1 minutes 9.623 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1659
# ######
# Mean Rd 0.344910
# Mean Tt 0.193439
#
# Calculation time: 1 minutes 12.134 seconds.
# {'g': 0.95, 'ma': 1, 'ms': 200, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.255 [％]
# Calculation time: 0 minutes 0.565 seconds.
#
# Progress: 0.794 [％]
# Calculation time: 0 minutes 1.347 seconds.
#
# Progress: 2.041 [％]
# Calculation time: 0 minutes 3.056 seconds.
#
# Progress: 4.895 [％]
# Calculation time: 0 minutes 6.540 seconds.
#
# Progress: 16.832 [％]
# Calculation time: 0 minutes 13.248 seconds.
#
# Progress: 57.747 [％]
# Calculation time: 0 minutes 22.168 seconds.
#
# Progress: 87.377 [％]
# Calculation time: 0 minutes 29.871 seconds.
#
# Progress: 98.818 [％]
# Calculation time: 0 minutes 34.127 seconds.
#
# Progress: 99.989 [％]
# Calculation time: 0 minutes 35.812 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 37.799 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1842
# ######
# Mean Rd 0.312810
# Mean Tt 0.391546
#
# Calculation time: 0 minutes 40.794 seconds.
# {'g': 0.95, 'ma': 1, 'ms': 200, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.256 [％]
# Calculation time: 0 minutes 0.567 seconds.
#
# Progress: 0.814 [％]
# Calculation time: 0 minutes 1.356 seconds.
#
# Progress: 2.042 [％]
# Calculation time: 0 minutes 3.074 seconds.
#
# Progress: 4.906 [％]
# Calculation time: 0 minutes 6.564 seconds.
#
# Progress: 11.821 [％]
# Calculation time: 0 minutes 13.322 seconds.
#
# Progress: 42.931 [％]
# Calculation time: 0 minutes 24.279 seconds.
#
# Progress: 77.407 [％]
# Calculation time: 0 minutes 35.601 seconds.
#
# Progress: 96.39 [％]
# Calculation time: 0 minutes 43.108 seconds.
#
# Progress: 99.913 [％]
# Calculation time: 0 minutes 46.008 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 47.547 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1842
# ######
# Mean Rd 0.337267
# Mean Tt 0.308920
#
# Calculation time: 0 minutes 49.460 seconds.
# {'g': 0.95, 'ma': 1, 'ms': 200, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.264 [％]
# Calculation time: 0 minutes 0.571 seconds.
#
# Progress: 0.812 [％]
# Calculation time: 0 minutes 1.363 seconds.
#
# Progress: 2.03 [％]
# Calculation time: 0 minutes 3.079 seconds.
#
# Progress: 4.888 [％]
# Calculation time: 0 minutes 6.574 seconds.
#
# Progress: 11.311 [％]
# Calculation time: 0 minutes 13.348 seconds.
#
# Progress: 24.739 [％]
# Calculation time: 0 minutes 25.406 seconds.
#
# Progress: 55.942 [％]
# Calculation time: 0 minutes 42.588 seconds.
#
# Progress: 84.908 [％]
# Calculation time: 0 minutes 59.384 seconds.
#
# Progress: 98.231 [％]
# Calculation time: 1 minutes 9.435 seconds.
#
# Progress: 99.972 [％]
# Calculation time: 1 minutes 13.018 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1842
# ######
# Mean Rd 0.365084
# Mean Tt 0.174191
#
# Calculation time: 1 minutes 16.125 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 50, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.45 [％]
# Calculation time: 0 minutes 1.367 seconds.
#
# Progress: 3.428 [％]
# Calculation time: 0 minutes 3.326 seconds.
#
# Progress: 29.689 [％]
# Calculation time: 0 minutes 7.116 seconds.
#
# Progress: 79.166 [％]
# Calculation time: 0 minutes 10.881 seconds.
#
# Progress: 93.533 [％]
# Calculation time: 0 minutes 13.311 seconds.
#
# Progress: 99.164 [％]
# Calculation time: 0 minutes 14.901 seconds.
#
# Progress: 99.984 [％]
# Calculation time: 0 minutes 15.711 seconds.
#
#
# ###### Finish ######
# Maximum step number: 235
# ######
# Mean Rd 0.066506
# Mean Tt 0.560401
#
# Calculation time: 0 minutes 16.077 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 50, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.288 [％]
# Calculation time: 0 minutes 1.376 seconds.
#
# Progress: 1.38 [％]
# Calculation time: 0 minutes 3.336 seconds.
#
# Progress: 13.28 [％]
# Calculation time: 0 minutes 7.421 seconds.
#
# Progress: 65.057 [％]
# Calculation time: 0 minutes 12.897 seconds.
#
# Progress: 88.446 [％]
# Calculation time: 0 minutes 16.712 seconds.
#
# Progress: 97.991 [％]
# Calculation time: 0 minutes 19.274 seconds.
#
# Progress: 99.934 [％]
# Calculation time: 0 minutes 20.534 seconds.
#
#
# ###### Finish ######
# Maximum step number: 235
# ######
# Mean Rd 0.071834
# Mean Tt 0.478809
#
# Calculation time: 0 minutes 21.196 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 50, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.257 [％]
# Calculation time: 0 minutes 1.366 seconds.
#
# Progress: 0.799 [％]
# Calculation time: 0 minutes 3.318 seconds.
#
# Progress: 2.601 [％]
# Calculation time: 0 minutes 7.500 seconds.
#
# Progress: 25.395 [％]
# Calculation time: 0 minutes 15.574 seconds.
#
# Progress: 71.275 [％]
# Calculation time: 0 minutes 24.135 seconds.
#
# Progress: 91.855 [％]
# Calculation time: 0 minutes 30.691 seconds.
#
# Progress: 99.323 [％]
# Calculation time: 0 minutes 34.079 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 35.347 seconds.
#
#
# ###### Finish ######
# Maximum step number: 293
# ######
# Mean Rd 0.079364
# Mean Tt 0.314613
#
# Calculation time: 0 minutes 35.508 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 100, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.257 [％]
# Calculation time: 0 minutes 0.831 seconds.
#
# Progress: 0.818 [％]
# Calculation time: 0 minutes 2.010 seconds.
#
# Progress: 2.42 [％]
# Calculation time: 0 minutes 4.577 seconds.
#
# Progress: 21.479 [％]
# Calculation time: 0 minutes 9.605 seconds.
#
# Progress: 68.722 [％]
# Calculation time: 0 minutes 15.326 seconds.
#
# Progress: 90.578 [％]
# Calculation time: 0 minutes 19.763 seconds.
#
# Progress: 99.152 [％]
# Calculation time: 0 minutes 22.213 seconds.
#
# Progress: 99.991 [％]
# Calculation time: 0 minutes 23.277 seconds.
#
#
# ###### Finish ######
# Maximum step number: 464
# ######
# Mean Rd 0.131264
# Mean Tt 0.443432
#
# Calculation time: 0 minutes 24.141 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 100, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.267 [％]
# Calculation time: 0 minutes 0.830 seconds.
#
# Progress: 0.811 [％]
# Calculation time: 0 minutes 2.023 seconds.
#
# Progress: 2.055 [％]
# Calculation time: 0 minutes 4.601 seconds.
#
# Progress: 8.71 [％]
# Calculation time: 0 minutes 9.801 seconds.
#
# Progress: 52.922 [％]
# Calculation time: 0 minutes 17.587 seconds.
#
# Progress: 82.903 [％]
# Calculation time: 0 minutes 24.354 seconds.
#
# Progress: 97.535 [％]
# Calculation time: 0 minutes 28.642 seconds.
#
# Progress: 99.947 [％]
# Calculation time: 0 minutes 30.376 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 31.481 seconds.
#
#
# ###### Finish ######
# Maximum step number: 581
# ######
# Mean Rd 0.141844
# Mean Tt 0.352456
#
# Calculation time: 0 minutes 31.750 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 100, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.268 [％]
# Calculation time: 0 minutes 0.833 seconds.
#
# Progress: 0.808 [％]
# Calculation time: 0 minutes 2.032 seconds.
#
# Progress: 2.042 [％]
# Calculation time: 0 minutes 4.596 seconds.
#
# Progress: 4.902 [％]
# Calculation time: 0 minutes 9.851 seconds.
#
# Progress: 19.341 [％]
# Calculation time: 0 minutes 20.121 seconds.
#
# Progress: 60.815 [％]
# Calculation time: 0 minutes 32.855 seconds.
#
# Progress: 89.029 [％]
# Calculation time: 0 minutes 43.475 seconds.
# Progress: 99.134 [％]
# Calculation time: 0 minutes 48.724 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 0 minutes 50.616 seconds.
#
#
# ###### Finish ######
# Maximum step number: 697
# ######
# Mean Rd 0.154098
# Mean Tt 0.194483
#
# Calculation time: 0 minutes 51.294 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 120, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.264 [％]
# Calculation time: 0 minutes 0.747 seconds.
#
# Progress: 0.807 [％]
# Calculation time: 0 minutes 1.815 seconds.
#
# Progress: 2.049 [％]
# Calculation time: 0 minutes 4.106 seconds.
#
# Progress: 10.34 [％]
# Calculation time: 0 minutes 8.737 seconds.
#
# Progress: 56.53 [％]
# Calculation time: 0 minutes 15.318 seconds.
#
# Progress: 84.653 [％]
# Calculation time: 0 minutes 20.869 seconds.
#
# Progress: 97.987 [％]
# Calculation time: 0 minutes 24.311 seconds.
#
# Progress: 99.961 [％]
# Calculation time: 0 minutes 25.747 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 26.507 seconds.
#
#
# ###### Finish ######
# Maximum step number: 556
# ######
# Mean Rd 0.155392
# Mean Tt 0.405922
#
# Calculation time: 0 minutes 26.624 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 120, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.248 [％]
# Calculation time: 0 minutes 0.733 seconds.
#
# Progress: 0.785 [％]
# Calculation time: 0 minutes 1.787 seconds.
#
# Progress: 2.024 [％]
# Calculation time: 0 minutes 4.082 seconds.
#
# Progress: 5.463 [％]
# Calculation time: 0 minutes 8.729 seconds.
#
# Progress: 37.182 [％]
# Calculation time: 0 minutes 16.886 seconds.
#
# Progress: 74.302 [％]
# Calculation time: 0 minutes 25.016 seconds.
#
# Progress: 94.905 [％]
# Calculation time: 0 minutes 30.810 seconds.
#
# Progress: 99.808 [％]
# Calculation time: 0 minutes 33.342 seconds.
#
# Progress: 99.998 [％]
# Calculation time: 0 minutes 34.589 seconds.
#
#
# ###### Finish ######
# Maximum step number: 556
# ######
# Mean Rd 0.166474
# Mean Tt 0.315142
#
# Calculation time: 0 minutes 34.763 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 120, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.259 [％]
# Calculation time: 0 minutes 0.732 seconds.
#
# Progress: 0.805 [％]
# Calculation time: 0 minutes 1.796 seconds.
#
# Progress: 2.008 [％]
# Calculation time: 0 minutes 4.094 seconds.
#
# Progress: 4.871 [％]
# Calculation time: 0 minutes 8.751 seconds.
#
# Progress: 12.849 [％]
# Calculation time: 0 minutes 17.746 seconds.
#
# Progress: 49.307 [％]
# Calculation time: 0 minutes 31.323 seconds.
#
# Progress: 81.963 [％]
# Calculation time: 0 minutes 44.173 seconds.
#
# Progress: 97.729 [％]
# Calculation time: 0 minutes 51.877 seconds.
#
# Progress: 99.964 [％]
# Calculation time: 0 minutes 54.626 seconds.
#
#
# ###### Finish ######
# Maximum step number: 696
# ######
# Mean Rd 0.179442
# Mean Tt 0.164769
#
# Calculation time: 0 minutes 55.379 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 180, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.248 [％]
# Calculation time: 0 minutes 0.595 seconds.
#
# Progress: 0.792 [％]
# Calculation time: 0 minutes 1.425 seconds.
#
# Progress: 1.99 [％]
# Calculation time: 0 minutes 3.254 seconds.
#
# Progress: 4.838 [％]
# Calculation time: 0 minutes 6.969 seconds.
#
# Progress: 22.44 [％]
# Calculation time: 0 minutes 13.908 seconds.
#
# Progress: 63.922 [％]
# Calculation time: 0 minutes 22.290 seconds.
#
# Progress: 90.562 [％]
# Calculation time: 0 minutes 29.050 seconds.
#
# Progress: 99.353 [％]
# Calculation time: 0 minutes 32.413 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 0 minutes 33.855 seconds.
#
#
# ###### Finish ######
# Maximum step number: 832
# ######
# Mean Rd 0.219626
# Mean Tt 0.315488
#
# Calculation time: 0 minutes 35.135 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 180, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.243 [％]
# Calculation time: 0 minutes 0.593 seconds.
#
# Progress: 0.787 [％]
# Calculation time: 0 minutes 1.421 seconds.
#
# Progress: 2.012 [％]
# Calculation time: 0 minutes 3.241 seconds.
#
# Progress: 4.868 [％]
# Calculation time: 0 minutes 6.949 seconds.
#
# Progress: 12.963 [％]
# Calculation time: 0 minutes 14.048 seconds.
#
# Progress: 49.489 [％]
# Calculation time: 0 minutes 24.769 seconds.
#
# Progress: 82.15 [％]
# Calculation time: 0 minutes 34.848 seconds.
#
# Progress: 97.727 [％]
# Calculation time: 0 minutes 41.105 seconds.
#
# Progress: 99.96 [％]
# Calculation time: 0 minutes 43.442 seconds.
#
#
# ###### Finish ######
# Maximum step number: 832
# ######
# Mean Rd 0.231468
# Mean Tt 0.230575
#
# Calculation time: 0 minutes 44.801 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 180, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.246 [％]
# Calculation time: 0 minutes 0.594 seconds.
#
# Progress: 0.802 [％]
# Calculation time: 0 minutes 1.426 seconds.
#
# Progress: 2.012 [％]
# Calculation time: 0 minutes 3.246 seconds.
#
# Progress: 4.908 [％]
# Calculation time: 0 minutes 6.959 seconds.
#
# Progress: 11.352 [％]
# Calculation time: 0 minutes 14.124 seconds.
#
# Progress: 27.128 [％]
# Calculation time: 0 minutes 26.827 seconds.
#
# Progress: 61.213 [％]
# Calculation time: 0 minutes 43.717 seconds.
#
# Progress: 88.628 [％]
# Calculation time: 0 minutes 58.799 seconds.
#
# Progress: 99.005 [％]
# Calculation time: 1 minutes 6.859 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 1 minutes 9.777 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1040
# ######
# Mean Rd 0.242115
# Mean Tt 0.105678
#
# Calculation time: 1 minutes 9.847 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 200, 'thickness': 0.16}
# Memory area size for voxel storage: 18.072 Mbyte
#
# ###### Start ######
#
# Progress: 0.244 [％]
# Calculation time: 0 minutes 0.560 seconds.
#
# Progress: 0.786 [％]
# Calculation time: 0 minutes 1.344 seconds.
#
# Progress: 2.019 [％]
# Calculation time: 0 minutes 3.071 seconds.
#
# Progress: 4.856 [％]
# Calculation time: 0 minutes 6.569 seconds.
#
# Progress: 16.501 [％]
# Calculation time: 0 minutes 13.286 seconds.
#
# Progress: 57.377 [％]
# Calculation time: 0 minutes 22.285 seconds.
#
# Progress: 87.023 [％]
# Calculation time: 0 minutes 30.167 seconds.
#
# Progress: 98.802 [％]
# Calculation time: 0 minutes 34.393 seconds.
#
# Progress: 99.989 [％]
# Calculation time: 0 minutes 36.058 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 0 minutes 37.913 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1155
# ######
# Mean Rd 0.238685
# Mean Tt 0.291779
#
# Calculation time: 0 minutes 38.367 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 200, 'thickness': 0.2}
# Memory area size for voxel storage: 22.088 Mbyte
#
# ###### Start ######
#
# Progress: 0.264 [％]
# Calculation time: 0 minutes 0.564 seconds.
#
# Progress: 0.801 [％]
# Calculation time: 0 minutes 1.351 seconds.
#
# Progress: 2.009 [％]
# Calculation time: 0 minutes 3.077 seconds.
#
# Progress: 4.833 [％]
# Calculation time: 0 minutes 6.573 seconds.
#
# Progress: 11.708 [％]
# Calculation time: 0 minutes 13.303 seconds.
#
# Progress: 42.63 [％]
# Calculation time: 0 minutes 24.502 seconds.
#
# Progress: 77.179 [％]
# Calculation time: 0 minutes 35.777 seconds.
#
# Progress: 96.332 [％]
# Calculation time: 0 minutes 43.286 seconds.
#
# Progress: 99.901 [％]
# Calculation time: 0 minutes 46.268 seconds.
#
#
# ###### Finish ######
# Maximum step number: 924
# ######
# Mean Rd 0.249601
# Mean Tt 0.210091
#
# Calculation time: 0 minutes 48.099 seconds.
# {'g': 0.95, 'ma': 2, 'ms': 200, 'thickness': 0.3}
# Memory area size for voxel storage: 32.128 Mbyte
#
# ###### Start ######
#
# Progress: 0.251 [％]
# Calculation time: 0 minutes 0.558 seconds.
#
# Progress: 0.803 [％]
# Calculation time: 0 minutes 1.349 seconds.
#
# Progress: 2.038 [％]
# Calculation time: 0 minutes 3.053 seconds.
#
# Progress: 4.923 [％]
# Calculation time: 0 minutes 6.522 seconds.
#
# Progress: 11.452 [％]
# Calculation time: 0 minutes 13.258 seconds.
#
# Progress: 24.833 [％]
# Calculation time: 0 minutes 25.253 seconds.
#
# Progress: 55.807 [％]
# Calculation time: 0 minutes 42.318 seconds.
#
# Progress: 84.787 [％]
# Calculation time: 0 minutes 59.105 seconds.
#
# Progress: 98.182 [％]
# Calculation time: 1 minutes 9.064 seconds.
#
# Progress: 99.996 [％]
# Calculation time: 1 minutes 12.752 seconds.
#
#
# ###### Finish ######
# Maximum step number: 1386
# ######
# Mean Rd 0.259955
# Mean Tt 0.092732
#
# Calculation time: 1 minutes 14.062 seconds.

# %%
df = pa.DataFrame()
df['Rd'] = Rd
df['Tt'] = Tt
df['g'] = g
df['ma'] = ma
df['ms'] = ms
df['thickness'] = thickness
df['dms']=df['ms']*(1-df['g'])

alpha = calc_alpha(100,0.01)
reg_co = []
r2list = []
Rd_int = np.array(Rd_int)
y = np.log10(Rd_int[:,20:80])
x = alpha[20:80]
for i in y:
    ind = np.where((~np.isnan(i))&(i!=np.inf)&(i!=-np.inf))[0]
    x_ = x[ind]
    y_ = i[ind]
    z = np.polyfit(x_, y_, 1)
    p = np.poly1d(z)
    reg_co.append(z)
    r2list.append(r2_score(y_,p(x_)))
reg_co = np.array(reg_co).T
plt.plot(r2list)
plt.xlabel('sample number')
plt.ylabel('r2 score')
plt.show()
df['c0'] = reg_co[0]
df['c1'] = reg_co[1]
df['r2'] = r2list

df.to_csv('si_in_inf.csv')

# %%
df
# Out:
#            Rd        Tt     g    ma   ms  thickness   dms        c0        c1  \
# 0    0.254565  0.718146  0.90  0.01   50       0.16   5.0 -3.725697  0.371345
# 1    0.306223  0.665538  0.90  0.01   50       0.20   5.0 -3.315008  0.365429
# 2    0.409926  0.559338  0.90  0.01   50       0.30   5.0 -2.720606  0.331680
# 3    0.428164  0.544026  0.90  0.01  100       0.16  10.0 -4.923296  0.802695
# 4    0.489322  0.481836  0.90  0.01  100       0.20  10.0 -4.432299  0.784967
# ..        ...       ...   ...   ...  ...        ...   ...       ...       ...
# 295  0.231468  0.230575  0.95  2.00  180       0.20   9.0 -5.646312  0.618272
# 296  0.242115  0.105678  0.95  2.00  180       0.30   9.0 -5.140469  0.528276
# 297  0.238685  0.291779  0.95  2.00  200       0.16  10.0 -6.363657  0.740276
# 298  0.249601  0.210091  0.95  2.00  200       0.20  10.0 -5.908650  0.679678
# 299  0.259955  0.092732  0.95  2.00  200       0.30  10.0 -5.359821  0.572150
#
#            r2
# 0    0.998134
# 1    0.999260
# 2    0.998757
# 3    0.997903
# 4    0.999348
# ..        ...
# 295  0.999217
# 296  0.999151
# 297  0.999258
# 298  0.999314
# 299  0.999146
#
# [300 rows x 10 columns]

# %%
alpha = calc_alpha(100,0.01)
df_rd = pa.DataFrame(np.array(Rd_int).T)
df_rd['alpha'] = alpha
df_rd.to_csv('Rd_int.csv',index=None)
df_tt = pa.DataFrame(np.array(Tt_int).T)
df_tt['alpha'] = alpha
df_tt.to_csv('Tt_int.csv',index=None)

# %%
plt.plot(df[df['thickness']==0.16]['dms'],df[df['thickness']==0.16]['Tt'],'.',label='d = 1.6 mm')
plt.plot(df[df['thickness']==0.2]['dms'],df[df['thickness']==0.2]['Tt'],'.',label='d = 2.0 mm')
plt.plot(df[df['thickness']==0.3]['dms'],df[df['thickness']==0.3]['Tt'],'.',label='d = 3.0 mm')
plt.legend()
plt.yscale('log')
plt.show()

# %%
plt.plot(df[df['ma']==0.5]['dms'],df[df['ma']==0.5]['Tt'],'.',label='d = 1.6 mm')
plt.yscale('log')
plt.show()

# %%
fig = plt.figure(figsize=(8,6),dpi = 90)
plt.plot(df[df['thickness']==0.16]['dms'],df[df['thickness']==0.16]['c0'],'.',label='d = 1.6 mm')
plt.plot(df[df['thickness']==0.2]['dms'],df[df['thickness']==0.2]['c0'],'.',label='d = 2.0 mm')
plt.plot(df[df['thickness']==0.3]['dms'],df[df['thickness']==0.3]['c0'],'.',label='d = 3.0 mm')
plt.legend()
plt.xlabel('µs\' [/cm]')
plt.ylabel('gradients')
plt.show()

fig = plt.figure(figsize=(8,6),dpi = 90)
plt.plot(df[df['thickness']==0.16]['dms'],df[df['thickness']==0.16]['c1'],'.',label='d = 1.6 mm')
plt.plot(df[df['thickness']==0.2]['dms'],df[df['thickness']==0.2]['c1'],'.',label='d = 2.0 mm')
plt.plot(df[df['thickness']==0.3]['dms'],df[df['thickness']==0.3]['c1'],'.',label='d = 3.0 mm')
plt.legend()
plt.xlabel('µs\' [/cm]')
plt.ylabel('intercepts')
plt.show()

# %%
val_ma = grid_params['ma']
for i in val_ma:
    fig = plt.figure(figsize=(8,6),dpi = 50)
    plt.plot(df[(df['thickness']==0.3)&(df['ma']==i)]['dms'],
             df[(df['thickness']==0.3)&(df['ma']==i)]['c0'],'.',label='d = 3.0 mm, µa = '+str(i))
    plt.plot(df[(df['thickness']==0.2)&(df['ma']==i)]['dms'],
             df[(df['thickness']==0.2)&(df['ma']==i)]['c0'],'.',label='d = 2.0 mm, µa = '+str(i))
    plt.plot(df[(df['thickness']==0.16)&(df['ma']==i)]['dms'],
             df[(df['thickness']==0.16)&(df['ma']==i)]['c0'],'.',label='d = 1.6 mm, µa = '+str(i))
    plt.legend()
    plt.xlabel('µs\' [/cm]')
    plt.ylabel('gradients')
    plt.show()

# %%
df['abs'] = np.log(df['ma']*df['thickness'])
plt.plot(df['abs'],df['c0'],'.',label='d = 3.0 mm')
plt.legend()
plt.xlabel('µs\' [/cm]')
plt.ylabel('gradients')
plt.show()

# %%
fig = plt.figure(figsize=(8,6),dpi = 90)
for i in df['abs'].unique():
    plt.plot(df[df['abs']==i]['dms'],df[df['abs']==i]['c0'],'.',label='abs = '+str(round(i,2)))
plt.legend()
plt.xlabel('µs\' [/cm]')
plt.ylabel('gradients')
plt.show()

# %%
df_array = df.values.T
index = np.where((df_array[3]==0.1) & (df_array[4]==120) & (df_array[2]==0.93))[0]
plt.figure(figsize=(5,4),dpi=100)
for i in index:
    label = 'skin = '+str(df.iloc[i,5])+' mm'
    plt.plot(alpha,np.log10(Rd_int[i]),label=label)
plt.legend()
plt.xlabel('r [cm]')
plt.ylabel('Rd $[cm^{-2}]$')
plt.show()

# %%
y = np.log10(Rd_int[-1,20:])
x = alpha[20:]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x,y)
plt.plot(x,p(x))
plt.show()

r2_score(y,p(x))
# Out:
# 0.995309276481893

# %%
nPh = 1e5
params = {
    'thickness':[0.3],
    'ms':[100],
    'ma':[1],
    'g':[0.9],
    'n':[1.37],
    'n_air':1.,
    'xy_size':10,
    'voxel_space':0.1,
}
model = VoxelPlateModel(nPh = nPh)
model.build(**params)
model = model.start()

res_it = model.get_result()
res_it

nn = 100
dr = 0.01

p_result = res_it["p"]
v_result = res_it["v"]
w_result = res_it["w"]

Tt_index = np.where(v_result[2]>0)[0]
Rd_index = np.where(v_result[2]<0)[0]

alphaRd,Rd = radialDistance(p_result[:,Rd_index],w_result[Rd_index],nn,dr)
alphaTt,Tt = radialDistance(p_result[:,Tt_index],w_result[Tt_index],nn,dr)

plt.figure(figsize=(5,4),dpi=100)
plt.plot(alphaRd,Rd,'-',c = 'red')
plt.yscale('log')
#plt.xlim(0,0.5)
#plt.ylim(10**-2,10**2)
plt.xlabel('r [cm]')
plt.ylabel('Rd $[cm^{-2}]$')
plt.show()

plt.figure(figsize=(5,4),dpi=100)
plt.plot(alphaTt,Tt,'-',c = 'blue')
plt.yscale('log')
#plt.xlim(0,0.5)
#plt.ylim(10**-2,1)
plt.xlabel('r [cm]')
plt.ylabel('Tt $[cm^{-2}]$')
plt.show()

# %%
df = pa.DataFrame()
df['Rd'] = Rd
df['Tt'] = Tt
df['g'] = g
df['ma'] = ma
df['ms'] = ms

df.to_csv('si_in_inf.csv')

# %%
df

# %%
dms = df['ms'].values*(1-df['g'].values)
dms

# %%
plt.figure(figsize=(8,6),dpi = 90)
plt.plot(dms,Tt,'.',c = 'k')
plt.yscale('log')
plt.xlabel('µs\' [/cm]')
plt.ylabel('Tt')
plt.show()

# %%
plt.figure(figsize=(8,6),dpi = 90)
plt.plot(dms,Rd,'.',c = 'k')
#plt.yscale('log')
plt.xlabel('µs\' [/cm]')
plt.ylabel('Rd')
plt.show()

# %%
fig = plt.figure(figsize=(8,6),dpi = 100)
ax = fig.add_subplot(111, projection='3d')

ax.scatter(ma, dms, Tt,c = 'k')
ax.set_xlabel('µa [/cm]')
ax.set_ylabel('µs\' [/cm]')
ax.set_zlabel('Tt')

plt.show()

# %%
fig = plt.figure(figsize=(8,6),dpi = 100)
ax = fig.add_subplot(111, projection='3d')

ax.scatter(ma, dms, Rd,c = 'k')
ax.set_xlabel('µa [/cm]')

ax.set_ylabel('µs\' [/cm]')
ax.set_zlabel('Rd')

plt.show()

# %%
df_input = pa.DataFrame({
    "dms":dms,
    "ma":ma,
    #'delta':delta,
    'Tt':Tt,
})
df_input.dropna()

# %%
import statsmodels.api as sm
df_input = pa.DataFrame({
    "dms":np.log(dms),
    "ma":(ma),
    'Tt':Tt,
})
df_input = df_input.dropna()
df_input = sm.add_constant(df_input)
y = np.log(df_input.Tt.values)
X = df_input.drop("Tt",axis=1)
#model = sm.GLM(y,X,family=sm.families.Poisson())
model = sm.OLS(y,X)
result = model.fit()
result.summary()

# %%
plt.plot(y,result.predict(),'.')
plt.show()

# %%
a = pa.read_csv('./test.csv')
a

# %%
import scipy.optimize

def fit_exp(parameter, x, y):
    a = parameter[0]
    b = parameter[1]
    residual = y - (a * np.exp(b * x))
    return residual

def fit_exp_linear(parameter, x, y):
    a = parameter[0]
    b = parameter[1]
    residual = np.log(y) - (np.log(a) + b * x)
    return residual

# %%
para1 = []
para2 = []
parameter0 = [1, 1]
for i in a.columns[1:]:
    b = a[['dms',i]].dropna()
    x = b.iloc[:,0]
    y = b.iloc[:,1]
    r1 = scipy.optimize.leastsq(fit_exp, parameter0, args=(x, y))
    r2 = scipy.optimize.leastsq(fit_exp_linear, parameter0, args=(x, y))
    para1.append(r1[0])
    para2.append(r2[0])
para1 = np.array(para1)
para2 = np.array(para2)
print(para2)
print(para1)

# %%
for n,i in enumerate(a.columns[1:]):
    plt.plot(np.sort(a['dms']),para1[n,0]*np.exp(para1[n,1]*np.sort(a['dms'])),'-',color = cp[n])
    plt.plot(a['dms'],a[i],'.',color = cp[n])
plt.yscale('log')
plt.show()

# %%
for n,i in enumerate(a.columns[1:]):
    plt.plot(np.sort(a['dms']),para2[n,0]*np.exp(para2[n,1]*np.sort(a['dms'])),'-',color = cp[n],label = i)
    plt.plot(a['dms'],a[i],'.',color = cp[n])
plt.yscale('log')
plt.xlabel('µs\' [/cm]')
plt.ylabel('Tt')
plt.legend()
plt.show()

# %%
plt.plot([0.01,0.1,0.5,0.9786,2],para2.T[0])
plt.yscale('log')
plt.show()

plt.plot([0.01,0.1,0.5,0.9786,2],para2.T[1])
plt.show()

# %%
plt.plot(a['dms'],r1[0][0]*np.exp(r1[0][1]*a['dms']),'.')
plt.plot(a['dms'],a['ma=0.1'],'.')
plt.show()
plt.plot(a['dms'],r2[0][0]*np.exp(r2[0][1]*a['dms']),'.')
plt.plot(a['dms'],a['ma=0.1'],'.')
plt.show()

# %%
c = pa.read_csv('./si_in_10x10x10mm.csv')
c

# %%
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
clf = SVR(kernel = 'linear')#‘linear’, ‘poly’, ‘rbf’, ‘sigmoid’, ‘precomputed’}
clf = Ridge()
d = c[['dms','ma','Tt']].dropna()
y = np.log(d.Tt)
X = d.drop('Tt',axis=1)
clf.fit(X,y)
pred = clf.predict(X)

# %%
plt.plot(y,pred,'.')
plt.show()

# %%
grid_params={
    'g':[0.9,0.92,0.93,0.95],
    'ma':[0.5,0.9786,2],
    'ms':[127,180,200],
}
len(list(ParameterGrid(grid_params)))

# %%
nPh = 3*1e5
grid_params={
    'g':[0.9,0.92,0.93,0.95],
    'ma':[0.5,0.9786,2],
    'ms':[127,180,200],
}

params = {
    'thickness':[1],
    'ms':[100],
    'ma':[1],
    'g':[0.9],
    'n':[1.375],
    'n_air':1.592,
    'xy_size':10,
    'voxel_space':1,
}
Rd_2 = [];Tt_2 =[]
g_2=[];ms_2=[];ma_2=[]
for i in ParameterGrid(grid_params):
    print(i)
    params.update(i)
    for j in ['ms','ma','g']:
        params[j] = [params[j]]
        
    model = VoxelPlateModel(nPh = nPh)
    model.build(**params)
    model = model.start()
    res = model.getRdTtValues()
    Rd_2.append(res['Rd'])
    Tt_2.append(res['Tt'])
    g_2.append(i['g'])
    ma_2.append(i['ma'])
    ms_2.append(i['ms'])

# %%
df2 = pa.DataFrame()
df2['Rd'] = Rd_2
df2['Tt'] = Tt_2
df2['g'] = g_2
df2['ma'] = ma_2
df2['ms'] = ms_2

df2.to_csv('si_in_inf2.csv')

# %%
dms2 = df2['ms'].values*(1-df2['g'].values)
dms2

# %%
plt.figure(figsize=(8,6),dpi = 90)
plt.plot(dms2,df2.Tt,'.',c = 'k')
plt.yscale('log')
plt.xlabel('µs\' [/cm]')
plt.ylabel('Tt')
plt.show()
