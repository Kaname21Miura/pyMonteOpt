# %%
from pymopt.solid import SolidPlateModel

from scipy import stats
import numpy as np
import pandas as pa
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("ticks", {'grid.linestyle': '--'})
import warnings
warnings.filterwarnings('ignore')

# %%
def radialDistance(p,w,nn,dr):
    alpha = np.array([(i)*dr for i in range(nn+1)])
    da = np.array([2*np.pi*(i+0.5)*dr**2 for i in range(nn)])
    r = np.sqrt(p[0]**2+p[1]**2)
    Rdr = []
    for i in range(nn):
        index = np.where((alpha[i]<r)&(alpha[i+1]>=r))[0]
        Rdr.append(w[index].sum())
    Rdr = np.array(Rdr)/(da*nPh)
    return alpha[:-1],Rdr

def AngularyResolved(v,w,nn):
    da = np.pi/(2*nn)
    alpha = np.array([(i+0.5)*da for i in range(nn+1)])
    alpha2 = np.array([(i)*da for i in range(nn+1)])
    do = 4*np.pi*np.sin(alpha)*np.sin(da/2)
    at = np.arccos(np.sign(v[2])*(v[2]))
    Rda = []
    for i in range(nn):
        index = np.where((alpha2[i]<at)&(alpha2[i+1]>=at))[0]
        Rda.append(w[index].sum())
    Rda = np.array(Rda)/(do[:-1]*nPh)
    return alpha[:-1],Rda

# %% [markdown]
# # Computation Results of single-solidmodel and mcml

# %% [markdown]
# ## Total diffuse reflectance and total transmittance

# %% [markdown]
# ### slab of turbid medium

# %%
nPh = 5000
model = SolidPlateModel(nPh = nPh)
params = {
    'thickness':[0.02],
    'ms':[90],
    'ma':[10],
    'g':[0.75],
    'n':[1.],
    'n_air':1.,
}
Rd=[];Tt=[]
for i in range(10):
    model = SolidPlateModel(nPh = nPh)
    model.built(**params)
    model = model.start()
    RdTt = model.getRdTtValues()
    Rd.append(RdTt['Rd'])
    Tt.append(RdTt['Tt'])
# Out:
# ###### Start ######
#
# Progress: 34.6 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.98 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.84 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.36 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 31
# ######
# Mean Rd 0.096818
# Mean Tt 0.659577
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 35.9 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.38 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.04 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.3 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 27
# ######
# Mean Rd 0.099780
# Mean Tt 0.657493
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 36.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.1 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.06 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.2 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 28
# ######
# Mean Rd 0.097798
# Mean Tt 0.660683
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 36.8 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 71.3 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.96 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.36 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.98 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 36
# ######
# Mean Rd 0.090682
# Mean Tt 0.670766
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 37.44 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.42 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.66 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.28 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 28
# ######
# Mean Rd 0.095893
# Mean Tt 0.665626
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 35.92 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.88 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.66 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 28
# ######
# Mean Rd 0.100745
# Mean Tt 0.655966
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 35.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.06 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.56 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.1 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.98 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 33
# ######
# Mean Rd 0.102572
# Mean Tt 0.654417
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 36.42 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 69.4 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.08 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 29
# ######
# Mean Rd 0.098491
# Mean Tt 0.660270
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 37.36 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 71.42 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 92.36 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.26 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 27
# ######
# Mean Rd 0.097192
# Mean Tt 0.666110
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 34.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.24 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 91.76 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.2 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 30
# ######
# Mean Rd 0.097270
# Mean Tt 0.659288
#
# Calculation time: 0 minutes 0 seconds.

# %%
print('Mean Rd %0.6f, sd_error %0.6f'%(np.mean(Rd),np.std(Rd)/np.sqrt(len(Rd))))
print('Mean Tt %0.6f, sd_error %0.6f'%(np.mean(Tt),np.std(Tt)/np.sqrt(len(Tt))))
# Out:
# Mean Rd 0.097724, sd_error 0.000958
# Mean Tt 0.661020, sd_error 0.001515

# %% [markdown]
# ### Semi-infinite turbid medium that has mismatched refractive index with the ambient medium

# %%
nPh = 5000
params = {
    'thickness':[10],
    'ms':[90],
    'ma':[10],
    'g':[0.],
    'n':[1.5],
    'n_air':1.,
}
Rd=[];Tt=[]
for i in range(10):
    model = SolidPlateModel(nPh = nPh)
    model.built(**params)
    model = model.start()
    RdTt = model.getRdTtValues()
    Rd.append(RdTt['Rd'])
    Tt.append(RdTt['Tt'])
# Out:
# ###### Start ######
#
# Progress: 5.06 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.14 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.6 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.4 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 62.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.8 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 153
# ######
# Mean Rd 0.217937
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.58 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.98 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.88 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 37.34 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 50.26 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 62.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.66 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 134
# ######
# Mean Rd 0.228455
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.32 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 21.92 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 34.8 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 48.7 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.72 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 133
# ######
# Mean Rd 0.213583
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.9 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.82 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.14 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.7 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 62.4 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.72 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 148
# ######
# Mean Rd 0.223573
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.88 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.76 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 22.74 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 34.9 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 48.66 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.32 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.7 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 153
# ######
# Mean Rd 0.217442
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.9 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.6 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.2 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.6 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 48.96 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.48 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 159
# ######
# Mean Rd 0.221024
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.92 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.54 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.04 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.08 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.6 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 175
# ######
# Mean Rd 0.222349
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 4.96 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.62 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.24 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 35.46 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.58 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 154
# ######
# Mean Rd 0.220245
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.32 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.56 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.6 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.48 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.64 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 61.74 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.68 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 158
# ######
# Mean Rd 0.222058
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.
#
# ###### Start ######
#
# Progress: 5.78 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 12.8 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 23.3 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 36.22 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 49.12 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 62.18 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 99.76 [％]
# Calculation time: 0 minutes 0 seconds.
#
#
# ###### Finish ######
# Maximum step number: 135
# ######
# Mean Rd 0.223044
# Mean Tt 0.000000
#
# Calculation time: 0 minutes 0 seconds.

# %%
print('Mean Rd %0.6f, sd_error %0.6f'%(np.mean(Rd),np.std(Rd)/np.sqrt(len(Rd))))
print('Mean Tt %0.6f, sd_error %0.6f'%(np.mean(Tt),np.std(Tt)/np.sqrt(len(Tt))))
# Out:
# Mean Rd 0.220971, sd_error 0.001212
# Mean Tt 0.000000, sd_error 0.000000

# %% [markdown]
# ## Angularly resolved diffuse reflectance and transmittance

# %%
nPh = 500000
model = SolidPlateModel(nPh = nPh)
params = {
    'thickness':[0.02],
    'ms':[90],
    'ma':[10],
    'g':[0.75],
    'n':[1.],
    'n_air':1.,
}
model.built(**params)
model = model.start()
# Out:
# ###### Start ######
#
# Progress: 36.128 [％]
# Calculation time: 0 minutes 0 seconds.
#
# Progress: 70.196 [％]
# Calculation time: 0 minutes 1 seconds.
#
# Progress: 91.89 [％]
# Calculation time: 0 minutes 1 seconds.
#
# Progress: 99.188 [％]
# Calculation time: 0 minutes 1 seconds.
#
# Progress: 99.992 [％]
# Calculation time: 0 minutes 1 seconds.
#
#
# ###### Finish ######
# Maximum step number: 45
# ######
# Mean Rd 0.097484
# Mean Tt 0.661164
#
# Calculation time: 0 minutes 2 seconds.

# %%
rez = model.getResult()
v_result = rez["v"]
w_result = rez["w"]
Tt_index = np.where(v_result[2]>0)[0]
Rd_index = np.where(v_result[2]<0)[0]

# %%
print('Trancemittance')
nn = 30
alpha,Tta = AngularyResolved(v_result[:,Tt_index],w_result[Tt_index],nn)

plt.figure(figsize=(5,4),dpi=90)
plt.plot(alpha/np.pi,Tta,'.')
plt.xlabel('Exit Angle α [rad/π]')
plt.ylabel('Tt(α) [/sr]')
plt.xlim(0,0.5)
plt.ylim(0,0.8)
plt.show()
# Out:
# Trancemittance

# %%
print('Refrected')
nn = 30
alpha,Rda = AngularyResolved(v_result[:,Rd_index],w_result[Rd_index],nn)

plt.figure(figsize=(5,4),dpi=90)
plt.plot(alpha/np.pi,Rda,'.')
plt.xlabel('Exit Angle α [rad/π]')
plt.ylabel('Rd(α) [/sr]')
#plt.xlim(0,0.5)
#plt.ylim(0,0.025)
plt.show()
# Out:
# Refrected

# %%
df_ = pa.DataFrame(np.array([alpha/np.pi,Rda,Tta]).T,columns = ['Angle','Rd','Tt'])
df_.to_csv('result/solid_angle.csv',index=None)

# %% [markdown]
# ## Radially resolved diffuse reflectance

# %%
nPh = 1000000

params = {
    'thickness':[20],
    'ms':[100],
    'ma':[0.1],
    'g':[0.9],
    'n':[1.],
    'n_air':1.,
}
model = SolidPlateModel(nPh = nPh)
model.built(**params)
model = model.start()
# Out:
# ###### Start ######
#
# Progress: 0.595 [％]
# Calculation time: 0 minutes 1 seconds.
#
# Progress: 1.956 [％]
# Calculation time: 0 minutes 2 seconds.
#
# Progress: 5.035 [％]
# Calculation time: 0 minutes 5 seconds.
#
# Progress: 11.933 [％]
# Calculation time: 0 minutes 10 seconds.
#
# Progress: 24.748 [％]
# Calculation time: 0 minutes 19 seconds.
#
# Progress: 41.018 [％]
# Calculation time: 0 minutes 34 seconds.
#
# Progress: 56.099 [％]
# Calculation time: 0 minutes 56 seconds.
#
# Progress: 68.156 [％]
# Calculation time: 1 minutes 29 seconds.
#
# Progress: 77.162 [％]
# Calculation time: 2 minutes 15 seconds.
#
# Progress: 83.73 [％]
# Calculation time: 3 minutes 18 seconds.
#
# Progress: 88.457 [％]
# Calculation time: 4 minutes 47 seconds.
#
# Progress: 91.823 [％]
# Calculation time: 6 minutes 51 seconds.
#
# Progress: 94.226 [％]
# Calculation time: 9 minutes 53 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 11 minutes 3 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 11 minutes 36 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 12 minutes 42 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 14 minutes 52 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 19 minutes 14 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 27 minutes 58 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 45 minutes 24 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 h 20 minutes.
#
# Progress: 100.0 [％]
# Calculation time: 2 h 30 minutes.
#
# Progress: 100.0 [％]
# Calculation time: 4 h 49 minutes.
#
# Progress: 100.0 [％]
# Calculation time: 9 h 28 minutes.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-ac618bea976c> in <module>
#      11 model = SolidPlateModel(nPh = nPh)
#      12 model.built(**params)
# ---> 13 model = model.start()
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\montecalro.py in start(self)
#      34         start_ = time.time()
#      35
# ---> 36         count = self.monteCycle(start_)
#      37         self.endProcess()
#      38
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\montecalro.py in monteCycle(self, start_)
#      51         # Let's MonteCalro!
#      52         while w_size != 0:
# ---> 53             w_size = self.stepMovement()
#      54             count+=1
#      55             if count%counter==0:
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in stepMovement(self)
#     357             #境界上光子のベクトルの更新
#     358             self.p[:,pb_index],self.v[:,pb_index],self.w[pb_index] = self.RTInterface(
# --> 359                 self.p[:,pb_index],self.v[:,pb_index],self.w[pb_index],dl,mt[pb_index])
#     360
#     361             #境界を超えない光子の位置,ベクトルを更新
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in RTInterface(self, p, v, w, dl, mt)
#     317             ind = np.where(n_ma != 0)[0]
#     318             mt = mt[ind]
# --> 319             pb_index,l,dl,ma,ms,g = self.boundaryJudgment(pp,vv,dl[ind]*mt)
#     320             pn_index = np.delete(np.arange(index.size),pb_index)
#     321             pp = self.positionUpdate(pp,vv,l)
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in boundaryJudgment(self, p, v, s)
#     157     # 境界判別と光子移動距離の更新
#     158     def boundaryJudgment(self,p,v,s):
# --> 159         ma,ms,g = self.getOpticalProperties(p,v)
#     160         mt = ma+ms
#     161         s = s/mt
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in getOpticalProperties(self, p, v)
#     184
#     185     def getOpticalProperties(self,p,v):
# --> 186         index = self.getBorderIndex(p,v)
#     187         p_size = p[2].size
#     188         A = self.create01Array(index,m=self.ma.size).T
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in getBorderIndex(self, p, v)
#     173         index_zero = np.where(abs(delta)<margin)
#     174         delta[index_zero[0],index_zero[1]] = 0
# --> 175         delta = np.sign(delta).astype('int16')
#     176         ind = np.array(np.where(delta==0))
#     177         ind_shallow = np.array(np.where(ind[1]==0)[0])
#
# KeyboardInterrupt:

# %%
params = {
    'thickness':[20],
    'ms':[10],
    'ma':[0.1],
    'g':[0.],
    'n':[1.],
    'n_air':1.,
}
model = SolidPlateModel(nPh = nPh)
model.built(**params)
model = model.start()

# %%
nn = 200
dr = 0.005

rezB = model.getResult()
p_resultB = rezB["p"]
v_resultB = rezB["v"]
w_resultB = rezB["w"]
Tt_indexB = np.where(v_resultB[2]>0)[0]
Rd_indexB = np.where(v_resultB[2]<0)[0]

alphaA,RdrA = radialDistance(p_resultA[:,Rd_indexA],w_resultA[Rd_indexA],nn,dr)
alphaB,RdrB = radialDistance(p_resultB[:,Rd_indexB],w_resultB[Rd_indexB],nn,dr)

# %%
plt.figure(figsize=(5,4),dpi=90)
plt.plot(alphaA,RdrA,'-',c = 'red',label = 'A: g = 0.9')
plt.plot(alphaB,RdrB,'-',c = 'blue',label = "B: g = 0.0")
plt.yscale('log')
plt.xlim(0,1)
plt.legend()
plt.xlabel('r [cm]')
plt.ylabel('Rd $[cm^{-2}]$')
plt.show()

# %%
plt.figure(figsize=(5,4),dpi=90)
plt.plot(alphaA,(RdrB-RdrA)/RdrA,'-',c = 'red',label = '(B-A) / A')
plt.xlim(0,1)
plt.ylim(-0.5,2)
plt.legend()
plt.xlabel('r [cm]')
plt.ylabel('Relative Error')
plt.show()

# %%
df_ = pa.DataFrame(np.array([alphaA,RdrA,RdrB]).T,columns = ['r cm','A_Rd','B_Rd'])
df_.to_csv('result/solid_equivalent.csv',index=None)

# %% [markdown]
# ## Depth resolved internal fluence

# %%
model_params = {
    'nPh': 1000000,
    'fluence': True,
    'nr': 500,
    'nz': 200,
    'dr': 0.01,
    'dz': 0.01,
}

print("######  n = 1.  ######")
params = {
    'thickness':[200],
    'ms':[100],
    'ma':[0.1],
    'g':[0.9],
    'n':[1.],
    'n_air':1.,
}
model = SolidPlateModel(**model_params)
model.built(**params)
model = model.start()
fluenceA = model.getFluence()

print('')
print("######  n = 1.37  ######")
params = {
    'thickness':[200],
    'ms':[100],
    'ma':[0.1],
    'g':[0.9],
    'n':[1.37],
    'n_air':1.,
}
model = SolidPlateModel(**model_params)
model.built(**params)
model = model.start()
fluenceB = model.getFluence()
# Out:
# ######  n = 1.  ######
# Memory area size for fluence storage: 0 Mbyte
#
# ###### Start ######
#
# Progress: 0.614 [％]
# Calculation time: 0 minutes 1 seconds.
#
# Progress: 1.951 [％]
# Calculation time: 0 minutes 3 seconds.
#
# Progress: 5.019 [％]
# Calculation time: 0 minutes 6 seconds.
#
# Progress: 11.931 [％]
# Calculation time: 0 minutes 13 seconds.
#
# Progress: 24.747 [％]
# Calculation time: 0 minutes 24 seconds.
#
# Progress: 40.99 [％]
# Calculation time: 0 minutes 43 seconds.
#
# Progress: 56.03 [％]
# Calculation time: 1 minutes 13 seconds.
#
# Progress: 68.107 [％]
# Calculation time: 1 minutes 58 seconds.
#
# Progress: 77.133 [％]
# Calculation time: 3 minutes 6 seconds.
#
# Progress: 83.698 [％]
# Calculation time: 4 minutes 49 seconds.
#
# Progress: 88.452 [％]
# Calculation time: 7 minutes 47 seconds.
#
# Progress: 91.815 [％]
# Calculation time: 12 minutes 39 seconds.
#
# Progress: 94.181 [％]
# Calculation time: 19 minutes 39 seconds.
#
# Progress: 99.999 [％]
# Calculation time: 21 minutes 44 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 22 minutes 16 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 23 minutes 22 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 25 minutes 32 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 29 minutes 52 seconds.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-0db079518128> in <module>
#      19 model = SolidPlateModel(**model_params)
#      20 model.built(**params)
# ---> 21 model = model.start()
#      22 fluenceA = model.getFluence()
#      23
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\montecalro.py in start(self)
#      34         start_ = time.time()
#      35
# ---> 36         count = self.monteCycle(start_)
#      37         self.endProcess()
#      38
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\montecalro.py in monteCycle(self, start_)
#      51         # Let's MonteCalro!
#      52         while w_size != 0:
# ---> 53             w_size = self.stepMovement()
#      54             count+=1
#      55             if count%counter==0:
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in stepMovement(self)
#     349         s = self.stepLength(self.p[0].size)
#     350         #境界を超える光子のindexを取得
# --> 351         pb_index,l,dl,ma,ms,g = self.boundaryJudgment(self.p,self.v,s)
#     352         mt = ma + ms
#     353         #光子位置を更新
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in boundaryJudgment(self, p, v, s)
#     157     # 境界判別と光子移動距離の更新
#     158     def boundaryJudgment(self,p,v,s):
# --> 159         ma,ms,g = self.getOpticalProperties(p,v)
#     160         mt = ma+ms
#     161         s = s/mt
#
# ~\Documents\GitHub\pyMonteOpt\pymopt\solid\_classes.py in getOpticalProperties(self, p, v)
#     188         A = self.create01Array(index,m=self.ma.size).T
#     189         ma_out = (np.tile(self.ma,(p_size,1))*A).max(1)
# --> 190         ms_out = (np.tile(self.ms,(p_size,1))*A).max(1)
#     191         g_out = (np.tile(self.g,(p_size,1))*A).max(1)
#     192         return ma_out,ms_out,g_out
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      28 def _amax(a, axis=None, out=None, keepdims=False,
#      29           initial=_NoValue, where=True):
# ---> 30     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      31
#      32 def _amin(a, axis=None, out=None, keepdims=False,
#
# KeyboardInterrupt:

# %%
da = np.array([2*np.pi*(i+0.5)*model_params['dr']**2 for i in range(model_params['nr'])])
aaa = params['ma'][0]*model_params['nPh']*model_params['dz']
phi_zA = (fluenceA["Arz"].T/aaa).T.sum(0)
phi_zB = (fluenceB["Arz"].T/aaa).T.sum(0)

plt.figure(figsize=(5,4),dpi=100)
plt.plot(fluenceA["z"],phi_zA,c = 'red',label = 'n = 1.0')
plt.plot(fluenceB["z"],phi_zB,c = 'blue',label = 'n = 1.37')
plt.xlabel('Z [cm]')
plt.ylabel('Fluence [-]')
plt.legend()
plt.yscale('log')
plt.xlim(0,1)
plt.ylim(0.5,10)
plt.show()

# %%
df_ = pa.DataFrame(np.array([fluence.getArrayZ(),phi_zA,phi_zB]).T,columns = ['z cm','n_1','n_1.37'])
df_.to_csv('result/solid_fluence_z.csv',index=None)

# %% [markdown]
# # Multi-layered Tissues

# %% [markdown]
# ## Refrective and transmittnace rate

# %%
nPh = 1000000
params = {
    'thickness':[0.1,0.1,0.2],
    'ms':[100,10,10],
    'ma':[1,1,2],
    'g':[0.9,0,0.7],
    'n':[1.37,1.37,1.37],
    'n_air':1.,
}
model = SolidPlateModel(nPh = nPh)
model.built(**params)
model = model.start()
# Out:
# ###### Start ######
#
# Progress: 0.214 [％]
# Calculation time: 0 minutes 2 seconds.
#
# Progress: 0.71 [％]
# Calculation time: 0 minutes 4 seconds.
#
# Progress: 2.229 [％]
# Calculation time: 0 minutes 9 seconds.
#
# Progress: 9.108 [％]
# Calculation time: 0 minutes 19 seconds.
#
# Progress: 29.652 [％]
# Calculation time: 0 minutes 39 seconds.
#
# Progress: 59.524 [％]
# Calculation time: 1 minutes 3 seconds.
#
# Progress: 87.243 [％]
# Calculation time: 1 minutes 25 seconds.
#
# Progress: 99.163 [％]
# Calculation time: 1 minutes 34 seconds.
#
# Progress: 100.0 [％]
# Calculation time: 1 minutes 37 seconds.
#
#
# ###### Finish ######
# Maximum step number: 526
# ######
# Mean Rd 0.213648
# Mean Tt 0.074598
#
# Calculation time: 1 minutes 37 seconds.

# %%
rez = model.getResult()
p_result = rez["p"]
v_result = rez["v"]
w_result = rez["w"]

Tt_index = np.where(v_result[2]>0)[0]
Rd_index = np.where(v_result[2]<0)[0]

# %%
nn = 100
dr = 0.005

alphaRd,Rd = radialDistance(p_result[:,Rd_index],w_result[Rd_index],nn,dr)
alphaTt,Tt = radialDistance(p_result[:,Tt_index],w_result[Tt_index],nn,dr)

plt.figure(figsize=(5,4),dpi=100)
plt.plot(alphaRd,Rd,'-',c = 'red')
plt.yscale('log')
plt.xlim(0,0.5)
plt.ylim(10**-2,10**2)
plt.xlabel('r [cm]')
plt.ylabel('Rd $[cm^{-2}]$')
plt.show()

plt.figure(figsize=(5,4),dpi=100)
plt.plot(alphaTt,Tt,'-',c = 'blue')
plt.yscale('log')
plt.xlim(0,0.5)
plt.ylim(10**-2,1)
plt.xlabel('r [cm]')
plt.ylabel('Tt $[cm^{-2}]$')
plt.show()

# %%
df_ = pa.DataFrame(np.array([alphaRd,Rd,Tt]).T,columns = ['r cm','Rd','Tt'])
df_.to_csv('result/solid_multi_rt_test.csv',index=None)
