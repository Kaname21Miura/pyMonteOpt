# %%
from pymopt.optics import OBD
obd = OBD()
load_path = "../result/201020_dicom4skin16_binary"

#"../result/201020_dicom4skin20ct03_binary"
#"../result/201020_dicom4skin30_binary"

# %%
obd.load_file(load_path)
print(load_path)
# Out:
# ../result/201020_dicom4skin30_binary

# %%
params ={
    'start':-10,'end':66,'split':2,
    'outerD_1':50,'efl_1':100,'bfl_1':93.41,
    'ct_1':10,'et_1':3.553,'r_1':51.68,'n_1':1.517,
    'outerD_2' : 50,'efl_2' : 50,'bfl_2' : 43.28,
    'ct_2':12,'et_2':3.01,'r_2':39.24,'n_2':1.758,
    'slit_outerD':50,'slit_D':20,'slit_width':2,'slit_thickness':5,
    'd_pd':3,
}
obd.set_params(params)

# %%
obd.start()
# Out:
# 100%|██████████| 38/38 [01:15<00:00,  1.99s/it]
# Calculation time: 1 minutes 16.120 seconds.

# %%
obd.save_result(load_path)
